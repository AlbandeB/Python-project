# %% [markdown]
# # Pipeline accident cost prediction

# %% [raw]
# Objective: Cost study and cost prediction of a pipeline incident

# %% [raw]
# The database is listing all accident reported in the USA from 2010 to 2017 with a wide range of qualitative and quantitative informations. Some retreatments are needed to improve the meaning of cost prediction and due to high number of NaNs values in the dataset.

# %% [raw]
# Steps in this notebook:
# -	Variables selection to do cost predictions
# -	Data visualization
# -   Outliers identification and costs structure plots
# -   New dataset and correlation matrix
# -	One-hot encoding & value replacement
# -	Modelling and regression
# -   Conclusion (Accuracy of predictions)

# %%
import numpy as np
import pandas as pd
from pandas.plotting import scatter_matrix
import seaborn as sns
import matplotlib as plt

# handle error messages
import warnings
warnings.filterwarnings("ignore")

# %%
path = './database.csv'
df = pd.read_csv(path,delimiter=',')
print(df.shape)
print(df.info())
# Out:
# (2795, 48)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2795 entries, 0 to 2794
# Data columns (total 48 columns):
# Report Number                           2795 non-null int64
# Supplemental Number                     2795 non-null int64
# Accident Year                           2795 non-null int64
# Accident Date/Time                      2795 non-null object
# Operator ID                             2795 non-null int64
# Operator Name                           2795 non-null object
# Pipeline/Facility Name                  2674 non-null object
# Pipeline Location                       2795 non-null object
# Pipeline Type                           2777 non-null object
# Liquid Type                             2795 non-null object
# Liquid Subtype                          1349 non-null object
# Liquid Name                             222 non-null object
# Accident City                           2480 non-null object
# Accident County                         2720 non-null object
# Accident State                          2783 non-null object
# Accident Latitude                       2795 non-null float64
# Accident Longitude                      2795 non-null float64
# Cause Category                          2795 non-null object
# Cause Subcategory                       2795 non-null object
# Unintentional Release (Barrels)         2795 non-null float64
# Intentional Release (Barrels)           1209 non-null float64
# Liquid Recovery (Barrels)               2795 non-null float64
# Net Loss (Barrels)                      2795 non-null float64
# Liquid Ignition                         2795 non-null object
# Liquid Explosion                        2795 non-null object
# Pipeline Shutdown                       2583 non-null object
# Shutdown Date/Time                      1390 non-null object
# Restart Date/Time                       1341 non-null object
# Public Evacuations                      2338 non-null float64
# Operator Employee Injuries              12 non-null float64
# Operator Contractor Injuries            12 non-null float64
# Emergency Responder Injuries            12 non-null float64
# Other Injuries                          12 non-null float64
# Public Injuries                         12 non-null float64
# All Injuries                            12 non-null float64
# Operator Employee Fatalities            8 non-null float64
# Operator Contractor Fatalities          8 non-null float64
# Emergency Responder Fatalities          8 non-null float64
# Other Fatalities                        8 non-null float64
# Public Fatalities                       8 non-null float64
# All Fatalities                          8 non-null float64
# Property Damage Costs                   2788 non-null float64
# Lost Commodity Costs                    2791 non-null float64
# Public/Private Property Damage Costs    2785 non-null float64
# Emergency Response Costs                2789 non-null float64
# Environmental Remediation Costs         2787 non-null float64
# Other Costs                             2779 non-null float64
# All Costs                               2795 non-null int64
# dtypes: float64(25), int64(5), object(18)
# memory usage: 1.0+ MB
# None

# %% [markdown]
# # Variables selection

# %%
# Remove columns whose data is more than 90% NaNs
mask = df.apply(lambda x: x.isna().sum()/len(x) < 0.9)
mask = [mask[c] for c in range(len(mask))]
df_reduced = df.loc[:, mask]

# Number of columns reduced from 48 to 35
print(df_reduced.shape)
df_reduced.T
# Out:
# (2795, 35)
#                                                                                    0     \
# Report Number                                                                  20100016
# Supplemental Number                                                               17305
# Accident Year                                                                      2010
# Accident Date/Time                                                     1/1/2010 7:15 AM
# Operator ID                                                                       32109
# Operator Name                                                     ONEOK NGL PIPELINE LP
# Pipeline/Facility Name                                                KINDER MORGAN JCT
# Pipeline Location                                                               ONSHORE
# Pipeline Type                                                               ABOVEGROUND
# Liquid Type                                  HVL OR OTHER FLAMMABLE OR TOXIC FLUID, GAS
# Liquid Subtype                        LPG (LIQUEFIED PETROLEUM GAS) / NGL (NATURAL G...
# Accident City                                                                 MCPHERSON
# Accident County                                                               MCPHERSON
# Accident State                                                                       KS
# Accident Latitude                                                               38.6707
# Accident Longitude                                                             -97.7812
# Cause Category                                                      INCORRECT OPERATION
# Cause Subcategory                                      PIPELINE/EQUIPMENT OVERPRESSURED
# Unintentional Release (Barrels)                                                      21
# Intentional Release (Barrels)                                                       0.1
# Liquid Recovery (Barrels)                                                             0
# Net Loss (Barrels)                                                                   21
# Liquid Ignition                                                                      NO
# Liquid Explosion                                                                     NO
# Pipeline Shutdown                                                                    NO
# Shutdown Date/Time                                                                  NaN
# Restart Date/Time                                                                   NaN
# Public Evacuations                                                                  NaN
# Property Damage Costs                                                               110
# Lost Commodity Costs                                                               1517
# Public/Private Property Damage Costs                                                  0
# Emergency Response Costs                                                              0
# Environmental Remediation Costs                                                       0
# Other Costs                                                                           0
# All Costs                                                                          1627
#
#                                                                 1     \
# Report Number                                               20100254
# Supplemental Number                                            17331
# Accident Year                                                   2010
# Accident Date/Time                                  1/4/2010 8:30 AM
# Operator ID                                                    15786
# Operator Name                                 PORTLAND PIPELINE CORP
# Pipeline/Facility Name                             24-INCH MAIN LINE
# Pipeline Location                                            ONSHORE
# Pipeline Type                                            ABOVEGROUND
# Liquid Type                                                CRUDE OIL
# Liquid Subtype                                                   NaN
# Accident City                                                RAYMOND
# Accident County                                           CUMBERLAND
# Accident State                                                    ME
# Accident Latitude                                            43.9403
# Accident Longitude                                          -70.4934
# Cause Category                           MATERIAL/WELD/EQUIP FAILURE
# Cause Subcategory                     PUMP OR PUMP-RELATED EQUIPMENT
# Unintentional Release (Barrels)                                 0.12
# Intentional Release (Barrels)                                      0
# Liquid Recovery (Barrels)                                       0.12
# Net Loss (Barrels)                                                 0
# Liquid Ignition                                                   NO
# Liquid Explosion                                                  NO
# Pipeline Shutdown                                                NaN
# Shutdown Date/Time                                               NaN
# Restart Date/Time                                                NaN
# Public Evacuations                                               NaN
# Property Damage Costs                                           4000
# Lost Commodity Costs                                               8
# Public/Private Property Damage Costs                               0
# Emergency Response Costs                                           0
# Environmental Remediation Costs                                    0
# Other Costs                                                        0
# All Costs                                                       4008
#
#                                                                             2     \
# Report Number                                                           20100038
# Supplemental Number                                                        17747
# Accident Year                                                               2010
# Accident Date/Time                                             1/5/2010 10:30 AM
# Operator ID                                                                20160
# Operator Name                                        PETROLOGISTICS OLEFINS, LLC
# Pipeline/Facility Name                                                       NaN
# Pipeline Location                                                        ONSHORE
# Pipeline Type                                                        ABOVEGROUND
# Liquid Type                           HVL OR OTHER FLAMMABLE OR TOXIC FLUID, GAS
# Liquid Subtype                                                         OTHER HVL
# Accident City                                                            SULPHER
# Accident County                                                        CALCASIEU
# Accident State                                                                LA
# Accident Latitude                                                        30.1824
# Accident Longitude                                                      -93.3524
# Cause Category                                       MATERIAL/WELD/EQUIP FAILURE
# Cause Subcategory                              DEFECTIVE OR LOOSE TUBING/FITTING
# Unintentional Release (Barrels)                                                2
# Intentional Release (Barrels)                                                  0
# Liquid Recovery (Barrels)                                                      0
# Net Loss (Barrels)                                                             2
# Liquid Ignition                                                               NO
# Liquid Explosion                                                              NO
# Pipeline Shutdown                                                            NaN
# Shutdown Date/Time                                                           NaN
# Restart Date/Time                                                            NaN
# Public Evacuations                                                           NaN
# Property Damage Costs                                                          0
# Lost Commodity Costs                                                         200
# Public/Private Property Damage Costs                                           0
# Emergency Response Costs                                                       0
# Environmental Remediation Costs                                                0
# Other Costs                                                                    0
# All Costs                                                                    200
#
#                                                                       3     \
# Report Number                                                     20100260
# Supplemental Number                                                  18574
# Accident Year                                                         2010
# Accident Date/Time                                        1/6/2010 7:30 PM
# Operator ID                                                          11169
# Operator Name                         ENBRIDGE ENERGY, LIMITED PARTNERSHIP
# Pipeline/Facility Name                                   SUPERIOR TERMINAL
# Pipeline Location                                                  ONSHORE
# Pipeline Type                                                  UNDERGROUND
# Liquid Type                                                      CRUDE OIL
# Liquid Subtype                                                         NaN
# Accident City                                                     SUPERIOR
# Accident County                                                    DOUGLAS
# Accident State                                                          WI
# Accident Latitude                                                  46.6893
# Accident Longitude                                                -92.0612
# Cause Category                                        NATURAL FORCE DAMAGE
# Cause Subcategory                                              TEMPERATURE
# Unintentional Release (Barrels)                                       0.48
# Intentional Release (Barrels)                                            0
# Liquid Recovery (Barrels)                                             0.48
# Net Loss (Barrels)                                                       0
# Liquid Ignition                                                         NO
# Liquid Explosion                                                        NO
# Pipeline Shutdown                                                      NaN
# Shutdown Date/Time                                                     NaN
# Restart Date/Time                                                      NaN
# Public Evacuations                                                     NaN
# Property Damage Costs                                                  200
# Lost Commodity Costs                                                    40
# Public/Private Property Damage Costs                                     0
# Emergency Response Costs                                             11300
# Environmental Remediation Costs                                          0
# Other Costs                                                              0
# All Costs                                                            11540
#
#                                                                4     \
# Report Number                                              20100030
# Supplemental Number                                           16276
# Accident Year                                                  2010
# Accident Date/Time                                 1/7/2010 1:00 PM
# Operator ID                                                     300
# Operator Name                                 PLAINS PIPELINE, L.P.
# Pipeline/Facility Name                               RED RIVER EAST
# Pipeline Location                                           ONSHORE
# Pipeline Type                                           UNDERGROUND
# Liquid Type                                               CRUDE OIL
# Liquid Subtype                                                  NaN
# Accident City                                               SHERMAN
# Accident County                                             GRAYSON
# Accident State                                                   TX
# Accident Latitude                                           33.5827
# Accident Longitude                                         -96.6488
# Cause Category                                    EXCAVATION DAMAGE
# Cause Subcategory                     THIRD PARTY EXCAVATION DAMAGE
# Unintentional Release (Barrels)                                 700
# Intentional Release (Barrels)                                   NaN
# Liquid Recovery (Barrels)                                       698
# Net Loss (Barrels)                                                2
# Liquid Ignition                                                  NO
# Liquid Explosion                                                 NO
# Pipeline Shutdown                                                NO
# Shutdown Date/Time                                              NaN
# Restart Date/Time                                               NaN
# Public Evacuations                                              NaN
# Property Damage Costs                                         20000
# Lost Commodity Costs                                            150
# Public/Private Property Damage Costs                              0
# Emergency Response Costs                                       7500
# Environmental Remediation Costs                                2000
# Other Costs                                                       0
# All Costs                                                     29650
#
#                                                                       5     \
# Report Number                                                     20100021
# Supplemental Number                                                  17161
# Accident Year                                                         2010
# Accident Date/Time                                       1/8/2010 11:38 PM
# Operator ID                                                          11169
# Operator Name                         ENBRIDGE ENERGY, LIMITED PARTNERSHIP
# Pipeline/Facility Name                                                 NaN
# Pipeline Location                                                  ONSHORE
# Pipeline Type                                                  UNDERGROUND
# Liquid Type                                                      CRUDE OIL
# Liquid Subtype                                                         NaN
# Accident City                                                        NECHE
# Accident County                                                    PEMBINA
# Accident State                                                          ND
# Accident Latitude                                                  48.9956
# Accident Longitude                                                -97.5255
# Cause Category                                 MATERIAL/WELD/EQUIP FAILURE
# Cause Subcategory                                    MANUFACTURING-RELATED
# Unintentional Release (Barrels)                                       3784
# Intentional Release (Barrels)                                            0
# Liquid Recovery (Barrels)                                             1547
# Net Loss (Barrels)                                                    2237
# Liquid Ignition                                                         NO
# Liquid Explosion                                                        NO
# Pipeline Shutdown                                                      YES
# Shutdown Date/Time                                          1/8/2010 23:41
# Restart Date/Time                                           1/13/2010 9:17
# Public Evacuations                                                       0
# Property Damage Costs                                                76940
# Lost Commodity Costs                                                167775
# Public/Private Property Damage Costs                                150000
# Emergency Response Costs                                           1.8e+06
# Environmental Remediation Costs                                      2e+06
# Other Costs                                                              0
# All Costs                                                          4194715
#
#                                                                                    6     \
# Report Number                                                                  20110036
# Supplemental Number                                                               18052
# Accident Year                                                                      2010
# Accident Date/Time                                                    1/9/2010 12:15 AM
# Operator ID                                                                       26041
# Operator Name                                       KINDER MORGAN LIQUID TERMINALS, LLC
# Pipeline/Facility Name                                                              NaN
# Pipeline Location                                                               ONSHORE
# Pipeline Type                                                                      TANK
# Liquid Type                           REFINED AND/OR PETROLEUM PRODUCT (NON-HVL), LI...
# Liquid Subtype                                                   GASOLINE (NON-ETHANOL)
# Accident City                                                               GALENA PARK
# Accident County                                                                  HARRIS
# Accident State                                                                       TX
# Accident Latitude                                                               29.4305
# Accident Longitude                                                             -95.1201
# Cause Category                                              MATERIAL/WELD/EQUIP FAILURE
# Cause Subcategory                                        ENVIRONMENTAL CRACKING-RELATED
# Unintentional Release (Barrels)                                                      35
# Intentional Release (Barrels)                                                         0
# Liquid Recovery (Barrels)                                                            30
# Net Loss (Barrels)                                                                    5
# Liquid Ignition                                                                      NO
# Liquid Explosion                                                                     NO
# Pipeline Shutdown                                                                    NO
# Shutdown Date/Time                                                                  NaN
# Restart Date/Time                                                                   NaN
# Public Evacuations                                                                  NaN
# Property Damage Costs                                                                 0
# Lost Commodity Costs                                                                400
# Public/Private Property Damage Costs                                                  0
# Emergency Response Costs                                                              0
# Environmental Remediation Costs                                                   70000
# Other Costs                                                                           0
# All Costs                                                                         70400
#
#                                                                                    7     \
# Report Number                                                                  20100255
# Supplemental Number                                                               18584
# Accident Year                                                                      2010
# Accident Date/Time                                                     1/9/2010 1:12 AM
# Operator ID                                                                       12624
# Operator Name                                                                MOBIL CORP
# Pipeline/Facility Name                                                     HULL STATION
# Pipeline Location                                                               ONSHORE
# Pipeline Type                                                               ABOVEGROUND
# Liquid Type                                  HVL OR OTHER FLAMMABLE OR TOXIC FLUID, GAS
# Liquid Subtype                        LPG (LIQUEFIED PETROLEUM GAS) / NGL (NATURAL G...
# Accident City                                                                      HULL
# Accident County                                                                 LIBERTY
# Accident State                                                                       TX
# Accident Latitude                                                               30.0853
# Accident Longitude                                                             -94.3805
# Cause Category                                                     NATURAL FORCE DAMAGE
# Cause Subcategory                                                           TEMPERATURE
# Unintentional Release (Barrels)                                                    0.24
# Intentional Release (Barrels)                                                         0
# Liquid Recovery (Barrels)                                                             0
# Net Loss (Barrels)                                                                 0.24
# Liquid Ignition                                                                      NO
# Liquid Explosion                                                                     NO
# Pipeline Shutdown                                                                   NaN
# Shutdown Date/Time                                                                  NaN
# Restart Date/Time                                                                   NaN
# Public Evacuations                                                                  NaN
# Property Damage Costs                                                               400
# Lost Commodity Costs                                                                 13
# Public/Private Property Damage Costs                                                  0
# Emergency Response Costs                                                              0
# Environmental Remediation Costs                                                       0
# Other Costs                                                                           0
# All Costs                                                                           413
#
#                                                                                    8     \
# Report Number                                                                  20100261
# Supplemental Number                                                               18050
# Accident Year                                                                      2010
# Accident Date/Time                                                    1/10/2010 7:46 PM
# Operator ID                                                                       26041
# Operator Name                                       KINDER MORGAN LIQUID TERMINALS, LLC
# Pipeline/Facility Name                                                              NaN
# Pipeline Location                                                               ONSHORE
# Pipeline Type                                                               ABOVEGROUND
# Liquid Type                           REFINED AND/OR PETROLEUM PRODUCT (NON-HVL), LI...
# Liquid Subtype                                     DIESEL, FUEL OIL, KEROSENE, JET FUEL
# Accident City                                                                       NaN
# Accident County                                                                     NaN
# Accident State                                                                       TX
# Accident Latitude                                                               29.4305
# Accident Longitude                                                             -95.1201
# Cause Category                                              MATERIAL/WELD/EQUIP FAILURE
# Cause Subcategory                                               OTHER EQUIPMENT FAILURE
# Unintentional Release (Barrels)                                                     0.4
# Intentional Release (Barrels)                                                         0
# Liquid Recovery (Barrels)                                                           0.4
# Net Loss (Barrels)                                                                    0
# Liquid Ignition                                                                      NO
# Liquid Explosion                                                                     NO
# Pipeline Shutdown                                                                   NaN
# Shutdown Date/Time                                                                  NaN
# Restart Date/Time                                                                   NaN
# Public Evacuations                                                                  NaN
# Property Damage Costs                                                                 0
# Lost Commodity Costs                                                                336
# Public/Private Property Damage Costs                                                  0
# Emergency Response Costs                                                              0
# Environmental Remediation Costs                                                   40000
# Other Costs                                                                           0
# All Costs                                                                         40336
#
#                                                                                    9     \
# Report Number                                                                  20100024
# Supplemental Number                                                               18390
# Accident Year                                                                      2010
# Accident Date/Time                                                    1/11/2010 2:30 PM
# Operator ID                                                                       31684
# Operator Name                                                            CONOCOPHILLIPS
# Pipeline/Facility Name                                                        TANK 1501
# Pipeline Location                                                               ONSHORE
# Pipeline Type                                                                      TANK
# Liquid Type                           REFINED AND/OR PETROLEUM PRODUCT (NON-HVL), LI...
# Liquid Subtype                                                   GASOLINE (NON-ETHANOL)
# Accident City                                                                  PASADENA
# Accident County                                                                  HARRIS
# Accident State                                                                       TX
# Accident Latitude                                                               29.7148
# Accident Longitude                                                             -95.1761
# Cause Category                                                         ALL OTHER CAUSES
# Cause Subcategory                                                         MISCELLANEOUS
# Unintentional Release (Barrels)                                                    0.48
# Intentional Release (Barrels)                                                         0
# Liquid Recovery (Barrels)                                                          0.48
# Net Loss (Barrels)                                                                    0
# Liquid Ignition                                                                      NO
# Liquid Explosion                                                                     NO
# Pipeline Shutdown                                                                    NO
# Shutdown Date/Time                                                                  NaN
# Restart Date/Time                                                                   NaN
# Public Evacuations                                                                  NaN
# Property Damage Costs                                                                 0
# Lost Commodity Costs                                                                 50
# Public/Private Property Damage Costs                                                  0
# Emergency Response Costs                                                          10000
# Environmental Remediation Costs                                                   10000
# Other Costs                                                                       10000
# All Costs                                                                         30050
#
#                                                   ...                \
# Report Number                                     ...
# Supplemental Number                               ...
# Accident Year                                     ...
# Accident Date/Time                                ...
# Operator ID                                       ...
# Operator Name                                     ...
# Pipeline/Facility Name                            ...
# Pipeline Location                                 ...
# Pipeline Type                                     ...
# Liquid Type                                       ...
# Liquid Subtype                                    ...
# Accident City                                     ...
# Accident County                                   ...
# Accident State                                    ...
# Accident Latitude                                 ...
# Accident Longitude                                ...
# Cause Category                                    ...
# Cause Subcategory                                 ...
# Unintentional Release (Barrels)                   ...
# Intentional Release (Barrels)                     ...
# Liquid Recovery (Barrels)                         ...
# Net Loss (Barrels)                                ...
# Liquid Ignition                                   ...
# Liquid Explosion                                  ...
# Pipeline Shutdown                                 ...
# Shutdown Date/Time                                ...
# Restart Date/Time                                 ...
# Public Evacuations                                ...
# Property Damage Costs                             ...
# Lost Commodity Costs                              ...
# Public/Private Property Damage Costs              ...
# Emergency Response Costs                          ...
# Environmental Remediation Costs                   ...
# Other Costs                                       ...
# All Costs                                         ...
#
#                                                                 2785  \
# Report Number                                               20170020
# Supplemental Number                                            22026
# Accident Year                                                   2016
# Accident Date/Time                               12/21/2016 11:40 AM
# Operator ID                                                    32147
# Operator Name                                 MARATHON PIPE LINE LLC
# Pipeline/Facility Name                                ELWOOD STATION
# Pipeline Location                                            ONSHORE
# Pipeline Type                                            ABOVEGROUND
# Liquid Type                                                CRUDE OIL
# Liquid Subtype                                                   NaN
# Accident City                                                 ELWOOD
# Accident County                                        TIPTON COUNTY
# Accident State                                                    IN
# Accident Latitude                                            40.2916
# Accident Longitude                                          -85.8628
# Cause Category                           MATERIAL/WELD/EQUIP FAILURE
# Cause Subcategory                     PUMP OR PUMP-RELATED EQUIPMENT
# Unintentional Release (Barrels)                                  1.7
# Intentional Release (Barrels)                                    NaN
# Liquid Recovery (Barrels)                                        1.7
# Net Loss (Barrels)                                                 0
# Liquid Ignition                                                   NO
# Liquid Explosion                                                  NO
# Pipeline Shutdown                                                YES
# Shutdown Date/Time                                  12/21/2016 11:40
# Restart Date/Time                                    12/22/2016 6:10
# Public Evacuations                                                 0
# Property Damage Costs                                          48264
# Lost Commodity Costs                                             103
# Public/Private Property Damage Costs                               0
# Emergency Response Costs                                       17674
# Environmental Remediation Costs                                    0
# Other Costs                                                        0
# All Costs                                                      66041
#
#                                                                 2786  \
# Report Number                                               20170022
# Supplemental Number                                            22029
# Accident Year                                                   2016
# Accident Date/Time                                12/22/2016 9:25 PM
# Operator ID                                                    32080
# Operator Name                               CCPS TRANSPORTATION, LLC
# Pipeline/Facility Name                           LINE 59 KEY STATION
# Pipeline Location                                            ONSHORE
# Pipeline Type                                            ABOVEGROUND
# Liquid Type                                                CRUDE OIL
# Liquid Subtype                                                   NaN
# Accident City                                              SALISBURY
# Accident County                                             CHARITON
# Accident State                                                    MO
# Accident Latitude                                             39.414
# Accident Longitude                                          -92.8402
# Cause Category                           MATERIAL/WELD/EQUIP FAILURE
# Cause Subcategory                     PUMP OR PUMP-RELATED EQUIPMENT
# Unintentional Release (Barrels)                                 12.5
# Intentional Release (Barrels)                                    NaN
# Liquid Recovery (Barrels)                                       12.5
# Net Loss (Barrels)                                                 0
# Liquid Ignition                                                   NO
# Liquid Explosion                                                  NO
# Pipeline Shutdown                                                YES
# Shutdown Date/Time                                  12/22/2016 21:53
# Restart Date/Time                                    12/23/2016 2:26
# Public Evacuations                                                 0
# Property Damage Costs                                          15020
# Lost Commodity Costs                                              27
# Public/Private Property Damage Costs                               0
# Emergency Response Costs                                       32000
# Environmental Remediation Costs                                    0
# Other Costs                                                        0
# All Costs                                                      47047
#
#                                                                2787  \
# Report Number                                              20170021
# Supplemental Number                                           22027
# Accident Year                                                  2016
# Accident Date/Time                               12/23/2016 3:00 PM
# Operator ID                                                   30829
# Operator Name                         ENTERPRISE CRUDE PIPELINE LLC
# Pipeline/Facility Name                                ECHO MANIFOLD
# Pipeline Location                                           ONSHORE
# Pipeline Type                                           ABOVEGROUND
# Liquid Type                                               CRUDE OIL
# Liquid Subtype                                                  NaN
# Accident City                                               HOUSTON
# Accident County                                              HARRIS
# Accident State                                                   TX
# Accident Latitude                                           29.6141
# Accident Longitude                                         -95.1848
# Cause Category                                     ALL OTHER CAUSES
# Cause Subcategory                                           UNKNOWN
# Unintentional Release (Barrels)                                   3
# Intentional Release (Barrels)                                   NaN
# Liquid Recovery (Barrels)                                         3
# Net Loss (Barrels)                                                0
# Liquid Ignition                                                  NO
# Liquid Explosion                                                 NO
# Pipeline Shutdown                                                NO
# Shutdown Date/Time                                              NaN
# Restart Date/Time                                               NaN
# Public Evacuations                                                0
# Property Damage Costs                                         65000
# Lost Commodity Costs                                             75
# Public/Private Property Damage Costs                              0
# Emergency Response Costs                                          0
# Environmental Remediation Costs                                   0
# Other Costs                                                       0
# All Costs                                                     65075
#
#                                                                  2788  \
# Report Number                                                20170023
# Supplemental Number                                             22030
# Accident Year                                                    2016
# Accident Date/Time                                 12/24/2016 9:35 AM
# Operator ID                                                     31684
# Operator Name                                PHILLIPS 66 PIPELINE LLC
# Pipeline/Facility Name                         NT-90, PREDO TO CARSON
# Pipeline Location                                             ONSHORE
# Pipeline Type                                             ABOVEGROUND
# Liquid Type                                                 CRUDE OIL
# Liquid Subtype                                                    NaN
# Accident City                                                     NaN
# Accident County                                                ARCHER
# Accident State                                                     TX
# Accident Latitude                                             33.6557
# Accident Longitude                                           -98.6248
# Cause Category                            MATERIAL/WELD/EQUIP FAILURE
# Cause Subcategory                     NON-THREADED CONNECTION FAILURE
# Unintentional Release (Barrels)                                   202
# Intentional Release (Barrels)                                     NaN
# Liquid Recovery (Barrels)                                         202
# Net Loss (Barrels)                                                  0
# Liquid Ignition                                                    NO
# Liquid Explosion                                                   NO
# Pipeline Shutdown                                                  NO
# Shutdown Date/Time                                                NaN
# Restart Date/Time                                                 NaN
# Public Evacuations                                                  0
# Property Damage Costs                                            4100
# Lost Commodity Costs                                            10600
# Public/Private Property Damage Costs                            50000
# Emergency Response Costs                                       105000
# Environmental Remediation Costs                                 87810
# Other Costs                                                      1000
# All Costs                                                      258510
#
#                                                                          2789  \
# Report Number                                                        20170026
# Supplemental Number                                                     22044
# Accident Year                                                            2016
# Accident Date/Time                                         12/26/2016 7:20 AM
# Operator ID                                                             32011
# Operator Name                         HOLLY ENERGY PARTNERS - OPERATING, L.P.
# Pipeline/Facility Name                                        RUSSELL STATION
# Pipeline Location                                                     ONSHORE
# Pipeline Type                                                     ABOVEGROUND
# Liquid Type                                                         CRUDE OIL
# Liquid Subtype                                                            NaN
# Accident City                                                             NaN
# Accident County                                                        GAINES
# Accident State                                                             TX
# Accident Latitude                                                     32.8618
# Accident Longitude                                                   -102.919
# Cause Category                                                      CORROSION
# Cause Subcategory                                                    INTERNAL
# Unintentional Release (Barrels)                                             3
# Intentional Release (Barrels)                                             NaN
# Liquid Recovery (Barrels)                                                   2
# Net Loss (Barrels)                                                          1
# Liquid Ignition                                                            NO
# Liquid Explosion                                                           NO
# Pipeline Shutdown                                                         YES
# Shutdown Date/Time                                            12/26/2016 7:20
# Restart Date/Time                                            12/26/2016 10:00
# Public Evacuations                                                          0
# Property Damage Costs                                                    1000
# Lost Commodity Costs                                                      120
# Public/Private Property Damage Costs                                        0
# Emergency Response Costs                                                 2000
# Environmental Remediation Costs                                         10000
# Other Costs                                                                 0
# All Costs                                                               13120
#
#                                                                       2790  \
# Report Number                                                     20170015
# Supplemental Number                                                  22020
# Accident Year                                                         2016
# Accident Date/Time                                      12/27/2016 8:40 AM
# Operator ID                                                          32334
# Operator Name                               TC OIL PIPELINE OPERATIONS INC
# Pipeline/Facility Name                                            KEYSTONE
# Pipeline Location                                                  ONSHORE
# Pipeline Type                                                  ABOVEGROUND
# Liquid Type                                                      CRUDE OIL
# Liquid Subtype                                                         NaN
# Accident City                                                         TINA
# Accident County                                                    CARROLL
# Accident State                                                          MO
# Accident Latitude                                                   39.517
# Accident Longitude                                                -93.4861
# Cause Category                                 MATERIAL/WELD/EQUIP FAILURE
# Cause Subcategory                     THREADED CONNECTION/COUPLING FAILURE
# Unintentional Release (Barrels)                                       0.25
# Intentional Release (Barrels)                                          NaN
# Liquid Recovery (Barrels)                                             0.25
# Net Loss (Barrels)                                                       0
# Liquid Ignition                                                         NO
# Liquid Explosion                                                        NO
# Pipeline Shutdown                                                      YES
# Shutdown Date/Time                                         12/27/2016 8:54
# Restart Date/Time                                         12/27/2016 16:11
# Public Evacuations                                                       0
# Property Damage Costs                                                    0
# Lost Commodity Costs                                                    15
# Public/Private Property Damage Costs                                     0
# Emergency Response Costs                                                 0
# Environmental Remediation Costs                                      61000
# Other Costs                                                              0
# All Costs                                                            61015
#
#                                                                             2791  \
# Report Number                                                           20170028
# Supplemental Number                                                        22046
# Accident Year                                                               2016
# Accident Date/Time                                            12/28/2016 4:20 PM
# Operator ID                                                                 4906
# Operator Name                                             EXXONMOBIL PIPELINE CO
# Pipeline/Facility Name                  BRRF - CHOCTAW ETHANE/PROPANE MIX SYSTEM
# Pipeline Location                                                        ONSHORE
# Pipeline Type                                                        UNDERGROUND
# Liquid Type                           HVL OR OTHER FLAMMABLE OR TOXIC FLUID, GAS
# Liquid Subtype                                                         OTHER HVL
# Accident City                                                                NaN
# Accident County                                                 WEST BATON ROUGE
# Accident State                                                                LA
# Accident Latitude                                                        30.3326
# Accident Longitude                                                      -91.2745
# Cause Category                                                  ALL OTHER CAUSES
# Cause Subcategory                                                        UNKNOWN
# Unintentional Release (Barrels)                                              580
# Intentional Release (Barrels)                                                  0
# Liquid Recovery (Barrels)                                                      0
# Net Loss (Barrels)                                                           580
# Liquid Ignition                                                               NO
# Liquid Explosion                                                              NO
# Pipeline Shutdown                                                            YES
# Shutdown Date/Time                                              12/28/2016 16:20
# Restart Date/Time                                                            NaN
# Public Evacuations                                                             0
# Property Damage Costs                                                          0
# Lost Commodity Costs                                                        5400
# Public/Private Property Damage Costs                                           0
# Emergency Response Costs                                                       0
# Environmental Remediation Costs                                                0
# Other Costs                                                               100000
# All Costs                                                                 105400
#
#                                                                    2792  \
# Report Number                                                  20170027
# Supplemental Number                                               22045
# Accident Year                                                      2016
# Accident Date/Time                                   12/29/2016 6:40 AM
# Operator ID                                                       39145
# Operator Name                         ENBRIDGE STORAGE (CUSHING) L.L.C.
# Pipeline/Facility Name                         CUSHING CENTRAL TERMINAL
# Pipeline Location                                               ONSHORE
# Pipeline Type                                                      TANK
# Liquid Type                                                   CRUDE OIL
# Liquid Subtype                                                      NaN
# Accident City                                                   CUSHING
# Accident County                                                   PAYNE
# Accident State                                                       OK
# Accident Latitude                                               35.5653
# Accident Longitude                                              -96.455
# Cause Category                              MATERIAL/WELD/EQUIP FAILURE
# Cause Subcategory                               OTHER EQUIPMENT FAILURE
# Unintentional Release (Barrels)                                       1
# Intentional Release (Barrels)                                       NaN
# Liquid Recovery (Barrels)                                             1
# Net Loss (Barrels)                                                    0
# Liquid Ignition                                                      NO
# Liquid Explosion                                                     NO
# Pipeline Shutdown                                                    NO
# Shutdown Date/Time                                                  NaN
# Restart Date/Time                                                   NaN
# Public Evacuations                                                    0
# Property Damage Costs                                              7000
# Lost Commodity Costs                                                 50
# Public/Private Property Damage Costs                                  0
# Emergency Response Costs                                           5000
# Environmental Remediation Costs                                    3000
# Other Costs                                                           0
# All Costs                                                         15050
#
#                                                                                    2793  \
# Report Number                                                                  20170024
# Supplemental Number                                                               22032
# Accident Year                                                                      2017
# Accident Date/Time                                                    1/3/2017 10:00 AM
# Operator ID                                                                       32147
# Operator Name                                                    MARATHON PIPE LINE LLC
# Pipeline/Facility Name                                                  MIDLAND STATION
# Pipeline Location                                                               ONSHORE
# Pipeline Type                                                               UNDERGROUND
# Liquid Type                           REFINED AND/OR PETROLEUM PRODUCT (NON-HVL), LI...
# Liquid Subtype                        MIXTURE OF REFINED PRODUCTS (TRANSMIX OR OTHER...
# Accident City                                                                  INDUSTRY
# Accident County                                                           BEAVER COUNTY
# Accident State                                                                       PA
# Accident Latitude                                                               40.6311
# Accident Longitude                                                             -80.4405
# Cause Category                                                         ALL OTHER CAUSES
# Cause Subcategory                                                               UNKNOWN
# Unintentional Release (Barrels)                                                     0.2
# Intentional Release (Barrels)                                                       NaN
# Liquid Recovery (Barrels)                                                           0.2
# Net Loss (Barrels)                                                                    0
# Liquid Ignition                                                                      NO
# Liquid Explosion                                                                     NO
# Pipeline Shutdown                                                                    NO
# Shutdown Date/Time                                                                  NaN
# Restart Date/Time                                                                   NaN
# Public Evacuations                                                                    0
# Property Damage Costs                                                             11852
# Lost Commodity Costs                                                                 11
# Public/Private Property Damage Costs                                                  0
# Emergency Response Costs                                                          29565
# Environmental Remediation Costs                                                       0
# Other Costs                                                                           0
# All Costs                                                                         41428
#
#                                                                2794
# Report Number                                              20170025
# Supplemental Number                                           22040
# Accident Year                                                  2017
# Accident Date/Time                                 1/9/2017 7:40 AM
# Operator ID                                                   30829
# Operator Name                         ENTERPRISE CRUDE PIPELINE LLC
# Pipeline/Facility Name                             MARSHALL STATION
# Pipeline Location                                           ONSHORE
# Pipeline Type                                           ABOVEGROUND
# Liquid Type                                               CRUDE OIL
# Liquid Subtype                                                  NaN
# Accident City                                              GONZALES
# Accident County                                            GONZALES
# Accident State                                                   TX
# Accident Latitude                                           29.3054
# Accident Longitude                                         -97.4003
# Cause Category                                  INCORRECT OPERATION
# Cause Subcategory                            INCORRECT INSTALLATION
# Unintentional Release (Barrels)                                   4
# Intentional Release (Barrels)                                   NaN
# Liquid Recovery (Barrels)                                         4
# Net Loss (Barrels)                                                0
# Liquid Ignition                                                  NO
# Liquid Explosion                                                 NO
# Pipeline Shutdown                                                NO
# Shutdown Date/Time                                              NaN
# Restart Date/Time                                               NaN
# Public Evacuations                                                0
# Property Damage Costs                                         45600
# Lost Commodity Costs                                            200
# Public/Private Property Damage Costs                              0
# Emergency Response Costs                                          0
# Environmental Remediation Costs                                   0
# Other Costs                                                       0
# All Costs                                                     45800
#
# [35 rows x 2795 columns]

# %% [raw]
# - Among these, interesting explanatory variables Xs could be: Operator ID, Pipeline Type, Liquid Type, cause subcategory, Net Loss (Barrels), Liquid Ignition, Liquid Explosion, Shutdown duration (created variable). ==> 8 explanatory variables
#
# - Injuries and Fatalities as well as columns relating to location of accidents won't be considered in our analysis because considered as meaningless for cost prediction. Some others are excluded because of high nans values proportion:
# Supplemental Number, Liquid Name, Pipeline Location (because imbalanced data), Accident City, Accident County, Accident Latitude, Accident Longitude, Public Evacuations,...

# %% [markdown]
# 'Shutdown duration' column creation

# %%
# Shutdown duration column creation
# Problem : only 1341 values
df_reduced['Shutdown Duration'] = (pd.to_datetime(df_reduced['Restart Date/Time']) - pd.to_datetime(df_reduced['Shutdown Date/Time']))\
.astype('timedelta64[h]')
df = df_reduced.fillna({'Shutdown Duration': 0}) # change nans into 0

# Statistics of Shutdown Duration
print(df['Shutdown Duration'].describe()) # hours
# Out:
# count     2795.000000
# mean        90.337746
# std        626.831444
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%         18.000000
# max      16746.000000
# Name: Shutdown Duration, dtype: float64

# %%
'''
Notice: Net loss (Barrels) discloses some non-integer figures (0,89 ; 4,16 ; ...)
        Shutdown Duration has 1341 values only
'''
print(df.shape)
df.T
# Out:
# (2795, 36)
#                                                                                    0     \
# Report Number                                                                  20100016
# Supplemental Number                                                               17305
# Accident Year                                                                      2010
# Accident Date/Time                                                     1/1/2010 7:15 AM
# Operator ID                                                                       32109
# Operator Name                                                     ONEOK NGL PIPELINE LP
# Pipeline/Facility Name                                                KINDER MORGAN JCT
# Pipeline Location                                                               ONSHORE
# Pipeline Type                                                               ABOVEGROUND
# Liquid Type                                  HVL OR OTHER FLAMMABLE OR TOXIC FLUID, GAS
# Liquid Subtype                        LPG (LIQUEFIED PETROLEUM GAS) / NGL (NATURAL G...
# Accident City                                                                 MCPHERSON
# Accident County                                                               MCPHERSON
# Accident State                                                                       KS
# Accident Latitude                                                               38.6707
# Accident Longitude                                                             -97.7812
# Cause Category                                                      INCORRECT OPERATION
# Cause Subcategory                                      PIPELINE/EQUIPMENT OVERPRESSURED
# Unintentional Release (Barrels)                                                      21
# Intentional Release (Barrels)                                                       0.1
# Liquid Recovery (Barrels)                                                             0
# Net Loss (Barrels)                                                                   21
# Liquid Ignition                                                                      NO
# Liquid Explosion                                                                     NO
# Pipeline Shutdown                                                                    NO
# Shutdown Date/Time                                                                  NaN
# Restart Date/Time                                                                   NaN
# Public Evacuations                                                                  NaN
# Property Damage Costs                                                               110
# Lost Commodity Costs                                                               1517
# Public/Private Property Damage Costs                                                  0
# Emergency Response Costs                                                              0
# Environmental Remediation Costs                                                       0
# Other Costs                                                                           0
# All Costs                                                                          1627
# Shutdown Duration                                                                     0
#
#                                                                 1     \
# Report Number                                               20100254
# Supplemental Number                                            17331
# Accident Year                                                   2010
# Accident Date/Time                                  1/4/2010 8:30 AM
# Operator ID                                                    15786
# Operator Name                                 PORTLAND PIPELINE CORP
# Pipeline/Facility Name                             24-INCH MAIN LINE
# Pipeline Location                                            ONSHORE
# Pipeline Type                                            ABOVEGROUND
# Liquid Type                                                CRUDE OIL
# Liquid Subtype                                                   NaN
# Accident City                                                RAYMOND
# Accident County                                           CUMBERLAND
# Accident State                                                    ME
# Accident Latitude                                            43.9403
# Accident Longitude                                          -70.4934
# Cause Category                           MATERIAL/WELD/EQUIP FAILURE
# Cause Subcategory                     PUMP OR PUMP-RELATED EQUIPMENT
# Unintentional Release (Barrels)                                 0.12
# Intentional Release (Barrels)                                      0
# Liquid Recovery (Barrels)                                       0.12
# Net Loss (Barrels)                                                 0
# Liquid Ignition                                                   NO
# Liquid Explosion                                                  NO
# Pipeline Shutdown                                                NaN
# Shutdown Date/Time                                               NaN
# Restart Date/Time                                                NaN
# Public Evacuations                                               NaN
# Property Damage Costs                                           4000
# Lost Commodity Costs                                               8
# Public/Private Property Damage Costs                               0
# Emergency Response Costs                                           0
# Environmental Remediation Costs                                    0
# Other Costs                                                        0
# All Costs                                                       4008
# Shutdown Duration                                                  0
#
#                                                                             2     \
# Report Number                                                           20100038
# Supplemental Number                                                        17747
# Accident Year                                                               2010
# Accident Date/Time                                             1/5/2010 10:30 AM
# Operator ID                                                                20160
# Operator Name                                        PETROLOGISTICS OLEFINS, LLC
# Pipeline/Facility Name                                                       NaN
# Pipeline Location                                                        ONSHORE
# Pipeline Type                                                        ABOVEGROUND
# Liquid Type                           HVL OR OTHER FLAMMABLE OR TOXIC FLUID, GAS
# Liquid Subtype                                                         OTHER HVL
# Accident City                                                            SULPHER
# Accident County                                                        CALCASIEU
# Accident State                                                                LA
# Accident Latitude                                                        30.1824
# Accident Longitude                                                      -93.3524
# Cause Category                                       MATERIAL/WELD/EQUIP FAILURE
# Cause Subcategory                              DEFECTIVE OR LOOSE TUBING/FITTING
# Unintentional Release (Barrels)                                                2
# Intentional Release (Barrels)                                                  0
# Liquid Recovery (Barrels)                                                      0
# Net Loss (Barrels)                                                             2
# Liquid Ignition                                                               NO
# Liquid Explosion                                                              NO
# Pipeline Shutdown                                                            NaN
# Shutdown Date/Time                                                           NaN
# Restart Date/Time                                                            NaN
# Public Evacuations                                                           NaN
# Property Damage Costs                                                          0
# Lost Commodity Costs                                                         200
# Public/Private Property Damage Costs                                           0
# Emergency Response Costs                                                       0
# Environmental Remediation Costs                                                0
# Other Costs                                                                    0
# All Costs                                                                    200
# Shutdown Duration                                                              0
#
#                                                                       3     \
# Report Number                                                     20100260
# Supplemental Number                                                  18574
# Accident Year                                                         2010
# Accident Date/Time                                        1/6/2010 7:30 PM
# Operator ID                                                          11169
# Operator Name                         ENBRIDGE ENERGY, LIMITED PARTNERSHIP
# Pipeline/Facility Name                                   SUPERIOR TERMINAL
# Pipeline Location                                                  ONSHORE
# Pipeline Type                                                  UNDERGROUND
# Liquid Type                                                      CRUDE OIL
# Liquid Subtype                                                         NaN
# Accident City                                                     SUPERIOR
# Accident County                                                    DOUGLAS
# Accident State                                                          WI
# Accident Latitude                                                  46.6893
# Accident Longitude                                                -92.0612
# Cause Category                                        NATURAL FORCE DAMAGE
# Cause Subcategory                                              TEMPERATURE
# Unintentional Release (Barrels)                                       0.48
# Intentional Release (Barrels)                                            0
# Liquid Recovery (Barrels)                                             0.48
# Net Loss (Barrels)                                                       0
# Liquid Ignition                                                         NO
# Liquid Explosion                                                        NO
# Pipeline Shutdown                                                      NaN
# Shutdown Date/Time                                                     NaN
# Restart Date/Time                                                      NaN
# Public Evacuations                                                     NaN
# Property Damage Costs                                                  200
# Lost Commodity Costs                                                    40
# Public/Private Property Damage Costs                                     0
# Emergency Response Costs                                             11300
# Environmental Remediation Costs                                          0
# Other Costs                                                              0
# All Costs                                                            11540
# Shutdown Duration                                                        0
#
#                                                                4     \
# Report Number                                              20100030
# Supplemental Number                                           16276
# Accident Year                                                  2010
# Accident Date/Time                                 1/7/2010 1:00 PM
# Operator ID                                                     300
# Operator Name                                 PLAINS PIPELINE, L.P.
# Pipeline/Facility Name                               RED RIVER EAST
# Pipeline Location                                           ONSHORE
# Pipeline Type                                           UNDERGROUND
# Liquid Type                                               CRUDE OIL
# Liquid Subtype                                                  NaN
# Accident City                                               SHERMAN
# Accident County                                             GRAYSON
# Accident State                                                   TX
# Accident Latitude                                           33.5827
# Accident Longitude                                         -96.6488
# Cause Category                                    EXCAVATION DAMAGE
# Cause Subcategory                     THIRD PARTY EXCAVATION DAMAGE
# Unintentional Release (Barrels)                                 700
# Intentional Release (Barrels)                                   NaN
# Liquid Recovery (Barrels)                                       698
# Net Loss (Barrels)                                                2
# Liquid Ignition                                                  NO
# Liquid Explosion                                                 NO
# Pipeline Shutdown                                                NO
# Shutdown Date/Time                                              NaN
# Restart Date/Time                                               NaN
# Public Evacuations                                              NaN
# Property Damage Costs                                         20000
# Lost Commodity Costs                                            150
# Public/Private Property Damage Costs                              0
# Emergency Response Costs                                       7500
# Environmental Remediation Costs                                2000
# Other Costs                                                       0
# All Costs                                                     29650
# Shutdown Duration                                                 0
#
#                                                                       5     \
# Report Number                                                     20100021
# Supplemental Number                                                  17161
# Accident Year                                                         2010
# Accident Date/Time                                       1/8/2010 11:38 PM
# Operator ID                                                          11169
# Operator Name                         ENBRIDGE ENERGY, LIMITED PARTNERSHIP
# Pipeline/Facility Name                                                 NaN
# Pipeline Location                                                  ONSHORE
# Pipeline Type                                                  UNDERGROUND
# Liquid Type                                                      CRUDE OIL
# Liquid Subtype                                                         NaN
# Accident City                                                        NECHE
# Accident County                                                    PEMBINA
# Accident State                                                          ND
# Accident Latitude                                                  48.9956
# Accident Longitude                                                -97.5255
# Cause Category                                 MATERIAL/WELD/EQUIP FAILURE
# Cause Subcategory                                    MANUFACTURING-RELATED
# Unintentional Release (Barrels)                                       3784
# Intentional Release (Barrels)                                            0
# Liquid Recovery (Barrels)                                             1547
# Net Loss (Barrels)                                                    2237
# Liquid Ignition                                                         NO
# Liquid Explosion                                                        NO
# Pipeline Shutdown                                                      YES
# Shutdown Date/Time                                          1/8/2010 23:41
# Restart Date/Time                                           1/13/2010 9:17
# Public Evacuations                                                       0
# Property Damage Costs                                                76940
# Lost Commodity Costs                                                167775
# Public/Private Property Damage Costs                                150000
# Emergency Response Costs                                           1.8e+06
# Environmental Remediation Costs                                      2e+06
# Other Costs                                                              0
# All Costs                                                          4194715
# Shutdown Duration                                                      105
#
#                                                                                    6     \
# Report Number                                                                  20110036
# Supplemental Number                                                               18052
# Accident Year                                                                      2010
# Accident Date/Time                                                    1/9/2010 12:15 AM
# Operator ID                                                                       26041
# Operator Name                                       KINDER MORGAN LIQUID TERMINALS, LLC
# Pipeline/Facility Name                                                              NaN
# Pipeline Location                                                               ONSHORE
# Pipeline Type                                                                      TANK
# Liquid Type                           REFINED AND/OR PETROLEUM PRODUCT (NON-HVL), LI...
# Liquid Subtype                                                   GASOLINE (NON-ETHANOL)
# Accident City                                                               GALENA PARK
# Accident County                                                                  HARRIS
# Accident State                                                                       TX
# Accident Latitude                                                               29.4305
# Accident Longitude                                                             -95.1201
# Cause Category                                              MATERIAL/WELD/EQUIP FAILURE
# Cause Subcategory                                        ENVIRONMENTAL CRACKING-RELATED
# Unintentional Release (Barrels)                                                      35
# Intentional Release (Barrels)                                                         0
# Liquid Recovery (Barrels)                                                            30
# Net Loss (Barrels)                                                                    5
# Liquid Ignition                                                                      NO
# Liquid Explosion                                                                     NO
# Pipeline Shutdown                                                                    NO
# Shutdown Date/Time                                                                  NaN
# Restart Date/Time                                                                   NaN
# Public Evacuations                                                                  NaN
# Property Damage Costs                                                                 0
# Lost Commodity Costs                                                                400
# Public/Private Property Damage Costs                                                  0
# Emergency Response Costs                                                              0
# Environmental Remediation Costs                                                   70000
# Other Costs                                                                           0
# All Costs                                                                         70400
# Shutdown Duration                                                                     0
#
#                                                                                    7     \
# Report Number                                                                  20100255
# Supplemental Number                                                               18584
# Accident Year                                                                      2010
# Accident Date/Time                                                     1/9/2010 1:12 AM
# Operator ID                                                                       12624
# Operator Name                                                                MOBIL CORP
# Pipeline/Facility Name                                                     HULL STATION
# Pipeline Location                                                               ONSHORE
# Pipeline Type                                                               ABOVEGROUND
# Liquid Type                                  HVL OR OTHER FLAMMABLE OR TOXIC FLUID, GAS
# Liquid Subtype                        LPG (LIQUEFIED PETROLEUM GAS) / NGL (NATURAL G...
# Accident City                                                                      HULL
# Accident County                                                                 LIBERTY
# Accident State                                                                       TX
# Accident Latitude                                                               30.0853
# Accident Longitude                                                             -94.3805
# Cause Category                                                     NATURAL FORCE DAMAGE
# Cause Subcategory                                                           TEMPERATURE
# Unintentional Release (Barrels)                                                    0.24
# Intentional Release (Barrels)                                                         0
# Liquid Recovery (Barrels)                                                             0
# Net Loss (Barrels)                                                                 0.24
# Liquid Ignition                                                                      NO
# Liquid Explosion                                                                     NO
# Pipeline Shutdown                                                                   NaN
# Shutdown Date/Time                                                                  NaN
# Restart Date/Time                                                                   NaN
# Public Evacuations                                                                  NaN
# Property Damage Costs                                                               400
# Lost Commodity Costs                                                                 13
# Public/Private Property Damage Costs                                                  0
# Emergency Response Costs                                                              0
# Environmental Remediation Costs                                                       0
# Other Costs                                                                           0
# All Costs                                                                           413
# Shutdown Duration                                                                     0
#
#                                                                                    8     \
# Report Number                                                                  20100261
# Supplemental Number                                                               18050
# Accident Year                                                                      2010
# Accident Date/Time                                                    1/10/2010 7:46 PM
# Operator ID                                                                       26041
# Operator Name                                       KINDER MORGAN LIQUID TERMINALS, LLC
# Pipeline/Facility Name                                                              NaN
# Pipeline Location                                                               ONSHORE
# Pipeline Type                                                               ABOVEGROUND
# Liquid Type                           REFINED AND/OR PETROLEUM PRODUCT (NON-HVL), LI...
# Liquid Subtype                                     DIESEL, FUEL OIL, KEROSENE, JET FUEL
# Accident City                                                                       NaN
# Accident County                                                                     NaN
# Accident State                                                                       TX
# Accident Latitude                                                               29.4305
# Accident Longitude                                                             -95.1201
# Cause Category                                              MATERIAL/WELD/EQUIP FAILURE
# Cause Subcategory                                               OTHER EQUIPMENT FAILURE
# Unintentional Release (Barrels)                                                     0.4
# Intentional Release (Barrels)                                                         0
# Liquid Recovery (Barrels)                                                           0.4
# Net Loss (Barrels)                                                                    0
# Liquid Ignition                                                                      NO
# Liquid Explosion                                                                     NO
# Pipeline Shutdown                                                                   NaN
# Shutdown Date/Time                                                                  NaN
# Restart Date/Time                                                                   NaN
# Public Evacuations                                                                  NaN
# Property Damage Costs                                                                 0
# Lost Commodity Costs                                                                336
# Public/Private Property Damage Costs                                                  0
# Emergency Response Costs                                                              0
# Environmental Remediation Costs                                                   40000
# Other Costs                                                                           0
# All Costs                                                                         40336
# Shutdown Duration                                                                     0
#
#                                                                                    9     \
# Report Number                                                                  20100024
# Supplemental Number                                                               18390
# Accident Year                                                                      2010
# Accident Date/Time                                                    1/11/2010 2:30 PM
# Operator ID                                                                       31684
# Operator Name                                                            CONOCOPHILLIPS
# Pipeline/Facility Name                                                        TANK 1501
# Pipeline Location                                                               ONSHORE
# Pipeline Type                                                                      TANK
# Liquid Type                           REFINED AND/OR PETROLEUM PRODUCT (NON-HVL), LI...
# Liquid Subtype                                                   GASOLINE (NON-ETHANOL)
# Accident City                                                                  PASADENA
# Accident County                                                                  HARRIS
# Accident State                                                                       TX
# Accident Latitude                                                               29.7148
# Accident Longitude                                                             -95.1761
# Cause Category                                                         ALL OTHER CAUSES
# Cause Subcategory                                                         MISCELLANEOUS
# Unintentional Release (Barrels)                                                    0.48
# Intentional Release (Barrels)                                                         0
# Liquid Recovery (Barrels)                                                          0.48
# Net Loss (Barrels)                                                                    0
# Liquid Ignition                                                                      NO
# Liquid Explosion                                                                     NO
# Pipeline Shutdown                                                                    NO
# Shutdown Date/Time                                                                  NaN
# Restart Date/Time                                                                   NaN
# Public Evacuations                                                                  NaN
# Property Damage Costs                                                                 0
# Lost Commodity Costs                                                                 50
# Public/Private Property Damage Costs                                                  0
# Emergency Response Costs                                                          10000
# Environmental Remediation Costs                                                   10000
# Other Costs                                                                       10000
# All Costs                                                                         30050
# Shutdown Duration                                                                     0
#
#                                                   ...                \
# Report Number                                     ...
# Supplemental Number                               ...
# Accident Year                                     ...
# Accident Date/Time                                ...
# Operator ID                                       ...
# Operator Name                                     ...
# Pipeline/Facility Name                            ...
# Pipeline Location                                 ...
# Pipeline Type                                     ...
# Liquid Type                                       ...
# Liquid Subtype                                    ...
# Accident City                                     ...
# Accident County                                   ...
# Accident State                                    ...
# Accident Latitude                                 ...
# Accident Longitude                                ...
# Cause Category                                    ...
# Cause Subcategory                                 ...
# Unintentional Release (Barrels)                   ...
# Intentional Release (Barrels)                     ...
# Liquid Recovery (Barrels)                         ...
# Net Loss (Barrels)                                ...
# Liquid Ignition                                   ...
# Liquid Explosion                                  ...
# Pipeline Shutdown                                 ...
# Shutdown Date/Time                                ...
# Restart Date/Time                                 ...
# Public Evacuations                                ...
# Property Damage Costs                             ...
# Lost Commodity Costs                              ...
# Public/Private Property Damage Costs              ...
# Emergency Response Costs                          ...
# Environmental Remediation Costs                   ...
# Other Costs                                       ...
# All Costs                                         ...
# Shutdown Duration                                 ...
#
#                                                                 2785  \
# Report Number                                               20170020
# Supplemental Number                                            22026
# Accident Year                                                   2016
# Accident Date/Time                               12/21/2016 11:40 AM
# Operator ID                                                    32147
# Operator Name                                 MARATHON PIPE LINE LLC
# Pipeline/Facility Name                                ELWOOD STATION
# Pipeline Location                                            ONSHORE
# Pipeline Type                                            ABOVEGROUND
# Liquid Type                                                CRUDE OIL
# Liquid Subtype                                                   NaN
# Accident City                                                 ELWOOD
# Accident County                                        TIPTON COUNTY
# Accident State                                                    IN
# Accident Latitude                                            40.2916
# Accident Longitude                                          -85.8628
# Cause Category                           MATERIAL/WELD/EQUIP FAILURE
# Cause Subcategory                     PUMP OR PUMP-RELATED EQUIPMENT
# Unintentional Release (Barrels)                                  1.7
# Intentional Release (Barrels)                                    NaN
# Liquid Recovery (Barrels)                                        1.7
# Net Loss (Barrels)                                                 0
# Liquid Ignition                                                   NO
# Liquid Explosion                                                  NO
# Pipeline Shutdown                                                YES
# Shutdown Date/Time                                  12/21/2016 11:40
# Restart Date/Time                                    12/22/2016 6:10
# Public Evacuations                                                 0
# Property Damage Costs                                          48264
# Lost Commodity Costs                                             103
# Public/Private Property Damage Costs                               0
# Emergency Response Costs                                       17674
# Environmental Remediation Costs                                    0
# Other Costs                                                        0
# All Costs                                                      66041
# Shutdown Duration                                                 18
#
#                                                                 2786  \
# Report Number                                               20170022
# Supplemental Number                                            22029
# Accident Year                                                   2016
# Accident Date/Time                                12/22/2016 9:25 PM
# Operator ID                                                    32080
# Operator Name                               CCPS TRANSPORTATION, LLC
# Pipeline/Facility Name                           LINE 59 KEY STATION
# Pipeline Location                                            ONSHORE
# Pipeline Type                                            ABOVEGROUND
# Liquid Type                                                CRUDE OIL
# Liquid Subtype                                                   NaN
# Accident City                                              SALISBURY
# Accident County                                             CHARITON
# Accident State                                                    MO
# Accident Latitude                                             39.414
# Accident Longitude                                          -92.8402
# Cause Category                           MATERIAL/WELD/EQUIP FAILURE
# Cause Subcategory                     PUMP OR PUMP-RELATED EQUIPMENT
# Unintentional Release (Barrels)                                 12.5
# Intentional Release (Barrels)                                    NaN
# Liquid Recovery (Barrels)                                       12.5
# Net Loss (Barrels)                                                 0
# Liquid Ignition                                                   NO
# Liquid Explosion                                                  NO
# Pipeline Shutdown                                                YES
# Shutdown Date/Time                                  12/22/2016 21:53
# Restart Date/Time                                    12/23/2016 2:26
# Public Evacuations                                                 0
# Property Damage Costs                                          15020
# Lost Commodity Costs                                              27
# Public/Private Property Damage Costs                               0
# Emergency Response Costs                                       32000
# Environmental Remediation Costs                                    0
# Other Costs                                                        0
# All Costs                                                      47047
# Shutdown Duration                                                  4
#
#                                                                2787  \
# Report Number                                              20170021
# Supplemental Number                                           22027
# Accident Year                                                  2016
# Accident Date/Time                               12/23/2016 3:00 PM
# Operator ID                                                   30829
# Operator Name                         ENTERPRISE CRUDE PIPELINE LLC
# Pipeline/Facility Name                                ECHO MANIFOLD
# Pipeline Location                                           ONSHORE
# Pipeline Type                                           ABOVEGROUND
# Liquid Type                                               CRUDE OIL
# Liquid Subtype                                                  NaN
# Accident City                                               HOUSTON
# Accident County                                              HARRIS
# Accident State                                                   TX
# Accident Latitude                                           29.6141
# Accident Longitude                                         -95.1848
# Cause Category                                     ALL OTHER CAUSES
# Cause Subcategory                                           UNKNOWN
# Unintentional Release (Barrels)                                   3
# Intentional Release (Barrels)                                   NaN
# Liquid Recovery (Barrels)                                         3
# Net Loss (Barrels)                                                0
# Liquid Ignition                                                  NO
# Liquid Explosion                                                 NO
# Pipeline Shutdown                                                NO
# Shutdown Date/Time                                              NaN
# Restart Date/Time                                               NaN
# Public Evacuations                                                0
# Property Damage Costs                                         65000
# Lost Commodity Costs                                             75
# Public/Private Property Damage Costs                              0
# Emergency Response Costs                                          0
# Environmental Remediation Costs                                   0
# Other Costs                                                       0
# All Costs                                                     65075
# Shutdown Duration                                                 0
#
#                                                                  2788  \
# Report Number                                                20170023
# Supplemental Number                                             22030
# Accident Year                                                    2016
# Accident Date/Time                                 12/24/2016 9:35 AM
# Operator ID                                                     31684
# Operator Name                                PHILLIPS 66 PIPELINE LLC
# Pipeline/Facility Name                         NT-90, PREDO TO CARSON
# Pipeline Location                                             ONSHORE
# Pipeline Type                                             ABOVEGROUND
# Liquid Type                                                 CRUDE OIL
# Liquid Subtype                                                    NaN
# Accident City                                                     NaN
# Accident County                                                ARCHER
# Accident State                                                     TX
# Accident Latitude                                             33.6557
# Accident Longitude                                           -98.6248
# Cause Category                            MATERIAL/WELD/EQUIP FAILURE
# Cause Subcategory                     NON-THREADED CONNECTION FAILURE
# Unintentional Release (Barrels)                                   202
# Intentional Release (Barrels)                                     NaN
# Liquid Recovery (Barrels)                                         202
# Net Loss (Barrels)                                                  0
# Liquid Ignition                                                    NO
# Liquid Explosion                                                   NO
# Pipeline Shutdown                                                  NO
# Shutdown Date/Time                                                NaN
# Restart Date/Time                                                 NaN
# Public Evacuations                                                  0
# Property Damage Costs                                            4100
# Lost Commodity Costs                                            10600
# Public/Private Property Damage Costs                            50000
# Emergency Response Costs                                       105000
# Environmental Remediation Costs                                 87810
# Other Costs                                                      1000
# All Costs                                                      258510
# Shutdown Duration                                                   0
#
#                                                                          2789  \
# Report Number                                                        20170026
# Supplemental Number                                                     22044
# Accident Year                                                            2016
# Accident Date/Time                                         12/26/2016 7:20 AM
# Operator ID                                                             32011
# Operator Name                         HOLLY ENERGY PARTNERS - OPERATING, L.P.
# Pipeline/Facility Name                                        RUSSELL STATION
# Pipeline Location                                                     ONSHORE
# Pipeline Type                                                     ABOVEGROUND
# Liquid Type                                                         CRUDE OIL
# Liquid Subtype                                                            NaN
# Accident City                                                             NaN
# Accident County                                                        GAINES
# Accident State                                                             TX
# Accident Latitude                                                     32.8618
# Accident Longitude                                                   -102.919
# Cause Category                                                      CORROSION
# Cause Subcategory                                                    INTERNAL
# Unintentional Release (Barrels)                                             3
# Intentional Release (Barrels)                                             NaN
# Liquid Recovery (Barrels)                                                   2
# Net Loss (Barrels)                                                          1
# Liquid Ignition                                                            NO
# Liquid Explosion                                                           NO
# Pipeline Shutdown                                                         YES
# Shutdown Date/Time                                            12/26/2016 7:20
# Restart Date/Time                                            12/26/2016 10:00
# Public Evacuations                                                          0
# Property Damage Costs                                                    1000
# Lost Commodity Costs                                                      120
# Public/Private Property Damage Costs                                        0
# Emergency Response Costs                                                 2000
# Environmental Remediation Costs                                         10000
# Other Costs                                                                 0
# All Costs                                                               13120
# Shutdown Duration                                                           2
#
#                                                                       2790  \
# Report Number                                                     20170015
# Supplemental Number                                                  22020
# Accident Year                                                         2016
# Accident Date/Time                                      12/27/2016 8:40 AM
# Operator ID                                                          32334
# Operator Name                               TC OIL PIPELINE OPERATIONS INC
# Pipeline/Facility Name                                            KEYSTONE
# Pipeline Location                                                  ONSHORE
# Pipeline Type                                                  ABOVEGROUND
# Liquid Type                                                      CRUDE OIL
# Liquid Subtype                                                         NaN
# Accident City                                                         TINA
# Accident County                                                    CARROLL
# Accident State                                                          MO
# Accident Latitude                                                   39.517
# Accident Longitude                                                -93.4861
# Cause Category                                 MATERIAL/WELD/EQUIP FAILURE
# Cause Subcategory                     THREADED CONNECTION/COUPLING FAILURE
# Unintentional Release (Barrels)                                       0.25
# Intentional Release (Barrels)                                          NaN
# Liquid Recovery (Barrels)                                             0.25
# Net Loss (Barrels)                                                       0
# Liquid Ignition                                                         NO
# Liquid Explosion                                                        NO
# Pipeline Shutdown                                                      YES
# Shutdown Date/Time                                         12/27/2016 8:54
# Restart Date/Time                                         12/27/2016 16:11
# Public Evacuations                                                       0
# Property Damage Costs                                                    0
# Lost Commodity Costs                                                    15
# Public/Private Property Damage Costs                                     0
# Emergency Response Costs                                                 0
# Environmental Remediation Costs                                      61000
# Other Costs                                                              0
# All Costs                                                            61015
# Shutdown Duration                                                        7
#
#                                                                             2791  \
# Report Number                                                           20170028
# Supplemental Number                                                        22046
# Accident Year                                                               2016
# Accident Date/Time                                            12/28/2016 4:20 PM
# Operator ID                                                                 4906
# Operator Name                                             EXXONMOBIL PIPELINE CO
# Pipeline/Facility Name                  BRRF - CHOCTAW ETHANE/PROPANE MIX SYSTEM
# Pipeline Location                                                        ONSHORE
# Pipeline Type                                                        UNDERGROUND
# Liquid Type                           HVL OR OTHER FLAMMABLE OR TOXIC FLUID, GAS
# Liquid Subtype                                                         OTHER HVL
# Accident City                                                                NaN
# Accident County                                                 WEST BATON ROUGE
# Accident State                                                                LA
# Accident Latitude                                                        30.3326
# Accident Longitude                                                      -91.2745
# Cause Category                                                  ALL OTHER CAUSES
# Cause Subcategory                                                        UNKNOWN
# Unintentional Release (Barrels)                                              580
# Intentional Release (Barrels)                                                  0
# Liquid Recovery (Barrels)                                                      0
# Net Loss (Barrels)                                                           580
# Liquid Ignition                                                               NO
# Liquid Explosion                                                              NO
# Pipeline Shutdown                                                            YES
# Shutdown Date/Time                                              12/28/2016 16:20
# Restart Date/Time                                                            NaN
# Public Evacuations                                                             0
# Property Damage Costs                                                          0
# Lost Commodity Costs                                                        5400
# Public/Private Property Damage Costs                                           0
# Emergency Response Costs                                                       0
# Environmental Remediation Costs                                                0
# Other Costs                                                               100000
# All Costs                                                                 105400
# Shutdown Duration                                                              0
#
#                                                                    2792  \
# Report Number                                                  20170027
# Supplemental Number                                               22045
# Accident Year                                                      2016
# Accident Date/Time                                   12/29/2016 6:40 AM
# Operator ID                                                       39145
# Operator Name                         ENBRIDGE STORAGE (CUSHING) L.L.C.
# Pipeline/Facility Name                         CUSHING CENTRAL TERMINAL
# Pipeline Location                                               ONSHORE
# Pipeline Type                                                      TANK
# Liquid Type                                                   CRUDE OIL
# Liquid Subtype                                                      NaN
# Accident City                                                   CUSHING
# Accident County                                                   PAYNE
# Accident State                                                       OK
# Accident Latitude                                               35.5653
# Accident Longitude                                              -96.455
# Cause Category                              MATERIAL/WELD/EQUIP FAILURE
# Cause Subcategory                               OTHER EQUIPMENT FAILURE
# Unintentional Release (Barrels)                                       1
# Intentional Release (Barrels)                                       NaN
# Liquid Recovery (Barrels)                                             1
# Net Loss (Barrels)                                                    0
# Liquid Ignition                                                      NO
# Liquid Explosion                                                     NO
# Pipeline Shutdown                                                    NO
# Shutdown Date/Time                                                  NaN
# Restart Date/Time                                                   NaN
# Public Evacuations                                                    0
# Property Damage Costs                                              7000
# Lost Commodity Costs                                                 50
# Public/Private Property Damage Costs                                  0
# Emergency Response Costs                                           5000
# Environmental Remediation Costs                                    3000
# Other Costs                                                           0
# All Costs                                                         15050
# Shutdown Duration                                                     0
#
#                                                                                    2793  \
# Report Number                                                                  20170024
# Supplemental Number                                                               22032
# Accident Year                                                                      2017
# Accident Date/Time                                                    1/3/2017 10:00 AM
# Operator ID                                                                       32147
# Operator Name                                                    MARATHON PIPE LINE LLC
# Pipeline/Facility Name                                                  MIDLAND STATION
# Pipeline Location                                                               ONSHORE
# Pipeline Type                                                               UNDERGROUND
# Liquid Type                           REFINED AND/OR PETROLEUM PRODUCT (NON-HVL), LI...
# Liquid Subtype                        MIXTURE OF REFINED PRODUCTS (TRANSMIX OR OTHER...
# Accident City                                                                  INDUSTRY
# Accident County                                                           BEAVER COUNTY
# Accident State                                                                       PA
# Accident Latitude                                                               40.6311
# Accident Longitude                                                             -80.4405
# Cause Category                                                         ALL OTHER CAUSES
# Cause Subcategory                                                               UNKNOWN
# Unintentional Release (Barrels)                                                     0.2
# Intentional Release (Barrels)                                                       NaN
# Liquid Recovery (Barrels)                                                           0.2
# Net Loss (Barrels)                                                                    0
# Liquid Ignition                                                                      NO
# Liquid Explosion                                                                     NO
# Pipeline Shutdown                                                                    NO
# Shutdown Date/Time                                                                  NaN
# Restart Date/Time                                                                   NaN
# Public Evacuations                                                                    0
# Property Damage Costs                                                             11852
# Lost Commodity Costs                                                                 11
# Public/Private Property Damage Costs                                                  0
# Emergency Response Costs                                                          29565
# Environmental Remediation Costs                                                       0
# Other Costs                                                                           0
# All Costs                                                                         41428
# Shutdown Duration                                                                     0
#
#                                                                2794
# Report Number                                              20170025
# Supplemental Number                                           22040
# Accident Year                                                  2017
# Accident Date/Time                                 1/9/2017 7:40 AM
# Operator ID                                                   30829
# Operator Name                         ENTERPRISE CRUDE PIPELINE LLC
# Pipeline/Facility Name                             MARSHALL STATION
# Pipeline Location                                           ONSHORE
# Pipeline Type                                           ABOVEGROUND
# Liquid Type                                               CRUDE OIL
# Liquid Subtype                                                  NaN
# Accident City                                              GONZALES
# Accident County                                            GONZALES
# Accident State                                                   TX
# Accident Latitude                                           29.3054
# Accident Longitude                                         -97.4003
# Cause Category                                  INCORRECT OPERATION
# Cause Subcategory                            INCORRECT INSTALLATION
# Unintentional Release (Barrels)                                   4
# Intentional Release (Barrels)                                   NaN
# Liquid Recovery (Barrels)                                         4
# Net Loss (Barrels)                                                0
# Liquid Ignition                                                  NO
# Liquid Explosion                                                 NO
# Pipeline Shutdown                                                NO
# Shutdown Date/Time                                              NaN
# Restart Date/Time                                               NaN
# Public Evacuations                                                0
# Property Damage Costs                                         45600
# Lost Commodity Costs                                            200
# Public/Private Property Damage Costs                              0
# Emergency Response Costs                                          0
# Environmental Remediation Costs                                   0
# Other Costs                                                       0
# All Costs                                                     45800
# Shutdown Duration                                                 0
#
# [36 rows x 2795 columns]

# %% [markdown]
# # Data visualization

# %%
# Top 10 accidents by the amount of All Costs
print(df['All Costs'].sort_values(ascending=False).head(10))

# Statistics of All Costs
print(df['All Costs'].describe())
# Out:
# 194     840526118
# 2103    142931884
# 523     135000000
# 1173     91300000
# 2675     66234072
# 241      47393566
# 457      35728903
# 160      32233740
# 133      28938000
# 1833     24323483
# Name: All Costs, dtype: int64
# count    2.795000e+03
# mean     8.340332e+05
# std      1.657830e+07
# min      0.000000e+00
# 25%      5.039500e+03
# 50%      2.312900e+04
# 75%      1.172325e+05
# max      8.405261e+08
# Name: All Costs, dtype: float64

# %%
df["Liquid Ignition"].value_counts(), df["Liquid Explosion"].value_counts()
# Out:
# (NO     2700
#  YES      95
#  Name: Liquid Ignition, dtype: int64, NO     2780
#  YES      15
#  Name: Liquid Explosion, dtype: int64)

# %%
# Some Operator IDs have multiple Operator Names due to M&A etc.
print("Number of distinct Operator ID:", len(df['Operator ID'].unique()))
print("Number of distinct Operator Name:", len(df['Operator Name'].unique()))
# Out:
# Number of distinct Operator ID: 213
# Number of distinct Operator Name: 229

# %%
df['Cause Category'].value_counts(), df['Cause Category'].describe()
# Out:
# (MATERIAL/WELD/EQUIP FAILURE    1435
#  CORROSION                       592
#  INCORRECT OPERATION             378
#  ALL OTHER CAUSES                118
#  NATURAL FORCE DAMAGE            118
#  EXCAVATION DAMAGE                97
#  OTHER OUTSIDE FORCE DAMAGE       57
#  Name: Cause Category, dtype: int64, count                            2795
#  unique                              7
#  top       MATERIAL/WELD/EQUIP FAILURE
#  freq                             1435
#  Name: Cause Category, dtype: object)

# %%
df["Pipeline Type"].value_counts(), df['Pipeline Type'].describe()
# Out:
# (ABOVEGROUND        1475
#  UNDERGROUND         985
#  TANK                301
#  TRANSITION AREA      16
#  Name: Pipeline Type, dtype: int64, count            2777
#  unique              4
#  top       ABOVEGROUND
#  freq             1475
#  Name: Pipeline Type, dtype: object)

# %%
df["Liquid Type"].value_counts(), df["Liquid Type"].describe()
# Out:
# (CRUDE OIL                                               1398
#  REFINED AND/OR PETROLEUM PRODUCT (NON-HVL), LIQUID       939
#  HVL OR OTHER FLAMMABLE OR TOXIC FLUID, GAS               418
#  CO2 (CARBON DIOXIDE)                                      38
#  BIOFUEL / ALTERNATIVE FUEL(INCLUDING ETHANOL BLENDS)       2
#  Name: Liquid Type, dtype: int64, count          2795
#  unique            5
#  top       CRUDE OIL
#  freq           1398
#  Name: Liquid Type, dtype: object)

# %%
print(df.groupby(['Accident Year'])['All Costs'].mean())
print(df.groupby(['Accident Year'])['All Costs'].count())
# Out:
# Accident Year
# 2010    3.071983e+06
# 2011    7.928306e+05
# 2012    3.968509e+05
# 2013    6.945774e+05
# 2014    2.900540e+05
# 2015    5.491256e+05
# 2016    4.172569e+05
# 2017    4.361400e+04
# Name: All Costs, dtype: float64
# Accident Year
# 2010    350
# 2011    345
# 2012    366
# 2013    401
# 2014    454
# 2015    462
# 2016    415
# 2017      2
# Name: All Costs, dtype: int64

# %%
print(pd.crosstab(df['Liquid Ignition'], df['Liquid Explosion']))
# Out:
# Liquid Explosion    NO  YES
# Liquid Ignition
# NO                2700    0
# YES                 80   15

# %%
print(df.groupby(['Liquid Ignition'])['All Costs'].mean())
print(df.groupby(['Liquid Explosion'])['All Costs'].mean())
print(df.groupby(['Liquid Ignition'])['All Costs'].max())
print(df.groupby(['Liquid Explosion'])['All Costs'].max())
# Out:
# Liquid Ignition
# NO     842947.114444
# YES    580691.726316
# Name: All Costs, dtype: float64
# Liquid Explosion
# NO     8.324311e+05
# YES    1.130972e+06
# Name: All Costs, dtype: float64
# Liquid Ignition
# NO     840526118
# YES     10262149
# Name: All Costs, dtype: int64
# Liquid Explosion
# NO     840526118
# YES      6910591
# Name: All Costs, dtype: int64

# %% [raw]
# Ignition or explosion of a liquid seems not lead to higher costs

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
Liquid_Type_count = df['Liquid Type'].value_counts()
sns.set(style="darkgrid")
sns.barplot(Liquid_Type_count.index, Liquid_Type_count.values, alpha=0.9, errwidth=0.1)
plt.title('Frequency Distribution of Liquid Type')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Liquid Type', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(df['Pipeline Type'])
plt.title('Pipeline Type')
# Out:
# Text(0.5, 1.0, 'Pipeline Type')

# %%
# Which Pipeline Type has highest cost
df_PipeLine_Type_All_Cost = df[['Pipeline Type','All Costs']]
sns.barplot(x='Pipeline Type', y="All Costs",  data=df_PipeLine_Type_All_Cost)
plt.title('Total costs per Pipeline Type')
# ==> outliers are underground pipelines
# Out:
# Text(0.5, 1.0, 'Total costs per Pipeline Type')

# %%
df.boxplot(column='Net Loss (Barrels)')
plt.title('# Net Loss (Barrels)')
# Out:
# Text(0.5,1,'# Net Loss (Barrels)')

# %% [markdown]
# # Outliers identification and costs structure plots

# %%
df['All Costs'].plot() # ==> 5 outliers identified
print(df.shape)
# Out:
# (2795, 36)

# %%
df['All Costs'].sort_values(ascending=False)[:10]
# Out:
# 194     840526118
# 2103    142931884
# 523     135000000
# 1173     91300000
# 2675     66234072
# 241      47393566
# 457      35728903
# 160      32233740
# 133      28938000
# 1833     24323483
# Name: All Costs, dtype: int64

# %% [raw]
# Accident cost structure of top 25:

# %%
b = df['All Costs'].sort_values(ascending=False) [:30]
top25 = df.iloc[b.index[1:26], 28:-2] # except index 194: outlier 1
top25.plot.bar(stacked=True)
plt.title('Accident Costs Structure')
plt.ylabel('Cost', fontsize=12)
plt.xlabel('Index', fontsize=12)
# Out:
# Text(0.5, 0, 'Index')

# %% [raw]
# Emergency Response Costs represent the major part of costs structure of top 25 accidents, followed by Environmental remediation costs. Accident 1 is excluded of this graph for scaling matter; its' main costs were Environmental Remediation Costs and Emergency Response Costs respectively.

# %%
print('Property Damage Costs:                ', "{:,}".format(df['Property Damage Costs'].sum()))
print('Environmental Remediation Costs:      ', "{:,}".format(df['Environmental Remediation Costs'].sum()))
print('Emergency Response Costs:             ', "{:,}".format(df['Emergency Response Costs'].sum()))
print('Lost Commodity Costs:                 ', "{:,}".format(df['Lost Commodity Costs'].sum()))
print('Public/Private Property Damage Costs: ', "{:,}".format(df['Public/Private Property Damage Costs'].sum()))
print('All Costs:                            ', "{:,}".format(df['All Costs'].sum()))
# Out:
# Property Damage Costs:                 313,081,992.0
# Environmental Remediation Costs:       1,011,149,910.0
# Emergency Response Costs:              814,084,371.0
# Lost Commodity Costs:                  27,366,589.0
# Public/Private Property Damage Costs:  69,964,627.0
# All Costs:                             2,331,122,923

# %% [raw]
# The 3 main costs categories are Environmental Remediation Costs, Emergency Response Costs and Property Damage Costs.

# %% [markdown]
# # New dataset and correlation matrix

# %%
# Select columns to be used for prediction
s = pd.Series([4,8,9,16,22,23,34,21,35])

# Highlight the selected columns
for col in range(len(df.columns)):
    if col in list(s):
        print("\033[31m" + str(col), df.columns[col] + "\033[0m")
    else:
        print(col, df.columns[col])
# Out:
# 0 Report Number
# 1 Supplemental Number
# 2 Accident Year
# 3 Accident Date/Time
# 4 Operator ID
# 5 Operator Name
# 6 Pipeline/Facility Name
# 7 Pipeline Location
# 8 Pipeline Type
# 9 Liquid Type
# 10 Liquid Subtype
# 11 Accident City
# 12 Accident County
# 13 Accident State
# 14 Accident Latitude
# 15 Accident Longitude
# 16 Cause Category
# 17 Cause Subcategory
# 18 Unintentional Release (Barrels)
# 19 Intentional Release (Barrels)
# 20 Liquid Recovery (Barrels)
# 21 Net Loss (Barrels)
# 22 Liquid Ignition
# 23 Liquid Explosion
# 24 Pipeline Shutdown
# 25 Shutdown Date/Time
# 26 Restart Date/Time
# 27 Public Evacuations
# 28 Property Damage Costs
# 29 Lost Commodity Costs
# 30 Public/Private Property Damage Costs
# 31 Emergency Response Costs
# 32 Environmental Remediation Costs
# 33 Other Costs
# 34 All Costs
# 35 Shutdown Duration

# %%
newdf = df[df.columns[s[:,]]].copy()
print(newdf.shape)
newdf.head()
# Out:
# (2795, 9)
#    Operator ID Pipeline Type                                 Liquid Type  \
# 0        32109   ABOVEGROUND  HVL OR OTHER FLAMMABLE OR TOXIC FLUID, GAS
# 1        15786   ABOVEGROUND                                   CRUDE OIL
# 2        20160   ABOVEGROUND  HVL OR OTHER FLAMMABLE OR TOXIC FLUID, GAS
# 3        11169   UNDERGROUND                                   CRUDE OIL
# 4          300   UNDERGROUND                                   CRUDE OIL
#
#                 Cause Category Liquid Ignition Liquid Explosion  All Costs  \
# 0          INCORRECT OPERATION              NO               NO       1627
# 1  MATERIAL/WELD/EQUIP FAILURE              NO               NO       4008
# 2  MATERIAL/WELD/EQUIP FAILURE              NO               NO        200
# 3         NATURAL FORCE DAMAGE              NO               NO      11540
# 4            EXCAVATION DAMAGE              NO               NO      29650
#
#    Net Loss (Barrels)  Shutdown Duration
# 0                21.0                0.0
# 1                 0.0                0.0
# 2                 2.0                0.0
# 3                 0.0                0.0
# 4                 2.0                0.0

# %% [raw]
# Among these: 6 categorical variables
# Operator ID will increase significantly the dimensionality after One-hot encoding

# %%
newdf.cov() # Covariance matrix is not easily readable!
# Out:
#                      Operator ID     All Costs  Net Loss (Barrels)  \
# Operator ID         1.545291e+08 -6.160399e+09        5.834308e+05
# All Costs          -6.160399e+09  2.748400e+14        1.216508e+09
# Net Loss (Barrels)  5.834308e+05  1.216508e+09        1.404271e+06
# Shutdown Duration   3.108264e+04  6.666732e+08        4.949745e+04
#
#                     Shutdown Duration
# Operator ID              3.108264e+04
# All Costs                6.666732e+08
# Net Loss (Barrels)       4.949745e+04
# Shutdown Duration        3.929177e+05

# %%
corr = newdf.corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %% [raw]
# All Costs are slightly correlated to Net loss (Barrels) and to shutdow Duration. No strong correlation can be identify among the quantitative variables. We have at least orthogonality but we expect high error rate in our prediction model and/or week R² if the regression is made only on these quantitative variables.
#
# Increasing number of outliers and exclude them from dataset tends to strengthen correlation.

# %% [markdown]
# # One-hot encoding & Value replacement

# %%
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()

# One-hot encoding
Pipeline_Type_dum = pd.get_dummies(newdf['Pipeline Type'], prefix='Pipeline Type')
newdf = pd.concat([newdf, Pipeline_Type_dum], axis=1)
newdf = newdf.drop(['Pipeline Type'], axis=1)

Liquid_Type_dum = pd.get_dummies(newdf['Liquid Type'], prefix='Liquid Type')
newdf = pd.concat([newdf, Liquid_Type_dum], axis=1)
newdf = newdf.drop(['Liquid Type'], axis=1)

Cause_Category_dum = pd.get_dummies(newdf['Cause Category'], prefix='Cause Category')
newdf = pd.concat([newdf, Cause_Category_dum], axis=1)
newdf = newdf.drop(['Cause Category'], axis=1)

Ignition_dum = pd.get_dummies(newdf['Liquid Ignition'], prefix='Liquid Ignition').replace({0:1, 1:0})
newdf = pd.concat([newdf, Ignition_dum], axis=1)
newdf = newdf.drop(['Liquid Ignition'], axis=1)

Explosion_dum = pd.get_dummies(newdf['Liquid Explosion'], prefix='Liquid Explosion').replace({0:1, 1:0})
newdf = pd.concat([newdf, Explosion_dum], axis=1)
newdf = newdf.drop(['Liquid Explosion'], axis=1)

Operator_ID_dum = pd.get_dummies(newdf['Operator ID'], prefix='Operator ID')
newdf = pd.concat([newdf, Operator_ID_dum], axis=1)
newdf = newdf.drop(['Operator ID'], axis=1)

print(newdf.shape)
newdf.T
# Out:
# (2795, 236)
#                                                       0       1      2     \
# All Costs                                           1627.0  4008.0  200.0
# Net Loss (Barrels)                                    21.0     0.0    2.0
# Shutdown Duration                                      0.0     0.0    0.0
# Pipeline Type_ABOVEGROUND                              1.0     1.0    1.0
# Pipeline Type_TANK                                     0.0     0.0    0.0
# Pipeline Type_TRANSITION AREA                          0.0     0.0    0.0
# Pipeline Type_UNDERGROUND                              0.0     0.0    0.0
# Liquid Type_BIOFUEL / ALTERNATIVE FUEL(INCLUDIN...     0.0     0.0    0.0
# Liquid Type_CO2 (CARBON DIOXIDE)                       0.0     0.0    0.0
# Liquid Type_CRUDE OIL                                  0.0     1.0    0.0
# Liquid Type_HVL OR OTHER FLAMMABLE OR TOXIC FLU...     1.0     0.0    1.0
# Liquid Type_REFINED AND/OR PETROLEUM PRODUCT (N...     0.0     0.0    0.0
# Cause Category_ALL OTHER CAUSES                        0.0     0.0    0.0
# Cause Category_CORROSION                               0.0     0.0    0.0
# Cause Category_EXCAVATION DAMAGE                       0.0     0.0    0.0
# Cause Category_INCORRECT OPERATION                     1.0     0.0    0.0
# Cause Category_MATERIAL/WELD/EQUIP FAILURE             0.0     1.0    1.0
# Cause Category_NATURAL FORCE DAMAGE                    0.0     0.0    0.0
# Cause Category_OTHER OUTSIDE FORCE DAMAGE              0.0     0.0    0.0
# Liquid Ignition_NO                                     0.0     0.0    0.0
# Liquid Ignition_YES                                    1.0     1.0    1.0
# Liquid Explosion_NO                                    0.0     0.0    0.0
# Liquid Explosion_YES                                   1.0     1.0    1.0
# Operator ID_300                                        0.0     0.0    0.0
# Operator ID_395                                        0.0     0.0    0.0
# Operator ID_515                                        0.0     0.0    0.0
# Operator ID_879                                        0.0     0.0    0.0
# Operator ID_999                                        0.0     0.0    0.0
# Operator ID_1248                                       0.0     0.0    0.0
# Operator ID_1541                                       0.0     0.0    0.0
# ...                                                    ...     ...    ...
# Operator ID_39023                                      0.0     0.0    0.0
# Operator ID_39029                                      0.0     0.0    0.0
# Operator ID_39043                                      0.0     0.0    0.0
# Operator ID_39047                                      0.0     0.0    0.0
# Operator ID_39055                                      0.0     0.0    0.0
# Operator ID_39068                                      0.0     0.0    0.0
# Operator ID_39080                                      0.0     0.0    0.0
# Operator ID_39084                                      0.0     0.0    0.0
# Operator ID_39085                                      0.0     0.0    0.0
# Operator ID_39090                                      0.0     0.0    0.0
# Operator ID_39098                                      0.0     0.0    0.0
# Operator ID_39104                                      0.0     0.0    0.0
# Operator ID_39105                                      0.0     0.0    0.0
# Operator ID_39145                                      0.0     0.0    0.0
# Operator ID_39149                                      0.0     0.0    0.0
# Operator ID_39183                                      0.0     0.0    0.0
# Operator ID_39191                                      0.0     0.0    0.0
# Operator ID_39229                                      0.0     0.0    0.0
# Operator ID_39264                                      0.0     0.0    0.0
# Operator ID_39286                                      0.0     0.0    0.0
# Operator ID_39302                                      0.0     0.0    0.0
# Operator ID_39307                                      0.0     0.0    0.0
# Operator ID_39349                                      0.0     0.0    0.0
# Operator ID_39440                                      0.0     0.0    0.0
# Operator ID_39467                                      0.0     0.0    0.0
# Operator ID_39504                                      0.0     0.0    0.0
# Operator ID_39509                                      0.0     0.0    0.0
# Operator ID_39534                                      0.0     0.0    0.0
# Operator ID_99031                                      0.0     0.0    0.0
# Operator ID_99043                                      0.0     0.0    0.0
#
#                                                        3        4     \
# All Costs                                           11540.0  29650.0
# Net Loss (Barrels)                                      0.0      2.0
# Shutdown Duration                                       0.0      0.0
# Pipeline Type_ABOVEGROUND                               0.0      0.0
# Pipeline Type_TANK                                      0.0      0.0
# Pipeline Type_TRANSITION AREA                           0.0      0.0
# Pipeline Type_UNDERGROUND                               1.0      1.0
# Liquid Type_BIOFUEL / ALTERNATIVE FUEL(INCLUDIN...      0.0      0.0
# Liquid Type_CO2 (CARBON DIOXIDE)                        0.0      0.0
# Liquid Type_CRUDE OIL                                   1.0      1.0
# Liquid Type_HVL OR OTHER FLAMMABLE OR TOXIC FLU...      0.0      0.0
# Liquid Type_REFINED AND/OR PETROLEUM PRODUCT (N...      0.0      0.0
# Cause Category_ALL OTHER CAUSES                         0.0      0.0
# Cause Category_CORROSION                                0.0      0.0
# Cause Category_EXCAVATION DAMAGE                        0.0      1.0
# Cause Category_INCORRECT OPERATION                      0.0      0.0
# Cause Category_MATERIAL/WELD/EQUIP FAILURE              0.0      0.0
# Cause Category_NATURAL FORCE DAMAGE                     1.0      0.0
# Cause Category_OTHER OUTSIDE FORCE DAMAGE               0.0      0.0
# Liquid Ignition_NO                                      0.0      0.0
# Liquid Ignition_YES                                     1.0      1.0
# Liquid Explosion_NO                                     0.0      0.0
# Liquid Explosion_YES                                    1.0      1.0
# Operator ID_300                                         0.0      1.0
# Operator ID_395                                         0.0      0.0
# Operator ID_515                                         0.0      0.0
# Operator ID_879                                         0.0      0.0
# Operator ID_999                                         0.0      0.0
# Operator ID_1248                                        0.0      0.0
# Operator ID_1541                                        0.0      0.0
# ...                                                     ...      ...
# Operator ID_39023                                       0.0      0.0
# Operator ID_39029                                       0.0      0.0
# Operator ID_39043                                       0.0      0.0
# Operator ID_39047                                       0.0      0.0
# Operator ID_39055                                       0.0      0.0
# Operator ID_39068                                       0.0      0.0
# Operator ID_39080                                       0.0      0.0
# Operator ID_39084                                       0.0      0.0
# Operator ID_39085                                       0.0      0.0
# Operator ID_39090                                       0.0      0.0
# Operator ID_39098                                       0.0      0.0
# Operator ID_39104                                       0.0      0.0
# Operator ID_39105                                       0.0      0.0
# Operator ID_39145                                       0.0      0.0
# Operator ID_39149                                       0.0      0.0
# Operator ID_39183                                       0.0      0.0
# Operator ID_39191                                       0.0      0.0
# Operator ID_39229                                       0.0      0.0
# Operator ID_39264                                       0.0      0.0
# Operator ID_39286                                       0.0      0.0
# Operator ID_39302                                       0.0      0.0
# Operator ID_39307                                       0.0      0.0
# Operator ID_39349                                       0.0      0.0
# Operator ID_39440                                       0.0      0.0
# Operator ID_39467                                       0.0      0.0
# Operator ID_39504                                       0.0      0.0
# Operator ID_39509                                       0.0      0.0
# Operator ID_39534                                       0.0      0.0
# Operator ID_99031                                       0.0      0.0
# Operator ID_99043                                       0.0      0.0
#
#                                                          5        6     \
# All Costs                                           4194715.0  70400.0
# Net Loss (Barrels)                                     2237.0      5.0
# Shutdown Duration                                       105.0      0.0
# Pipeline Type_ABOVEGROUND                                 0.0      0.0
# Pipeline Type_TANK                                        0.0      1.0
# Pipeline Type_TRANSITION AREA                             0.0      0.0
# Pipeline Type_UNDERGROUND                                 1.0      0.0
# Liquid Type_BIOFUEL / ALTERNATIVE FUEL(INCLUDIN...        0.0      0.0
# Liquid Type_CO2 (CARBON DIOXIDE)                          0.0      0.0
# Liquid Type_CRUDE OIL                                     1.0      0.0
# Liquid Type_HVL OR OTHER FLAMMABLE OR TOXIC FLU...        0.0      0.0
# Liquid Type_REFINED AND/OR PETROLEUM PRODUCT (N...        0.0      1.0
# Cause Category_ALL OTHER CAUSES                           0.0      0.0
# Cause Category_CORROSION                                  0.0      0.0
# Cause Category_EXCAVATION DAMAGE                          0.0      0.0
# Cause Category_INCORRECT OPERATION                        0.0      0.0
# Cause Category_MATERIAL/WELD/EQUIP FAILURE                1.0      1.0
# Cause Category_NATURAL FORCE DAMAGE                       0.0      0.0
# Cause Category_OTHER OUTSIDE FORCE DAMAGE                 0.0      0.0
# Liquid Ignition_NO                                        0.0      0.0
# Liquid Ignition_YES                                       1.0      1.0
# Liquid Explosion_NO                                       0.0      0.0
# Liquid Explosion_YES                                      1.0      1.0
# Operator ID_300                                           0.0      0.0
# Operator ID_395                                           0.0      0.0
# Operator ID_515                                           0.0      0.0
# Operator ID_879                                           0.0      0.0
# Operator ID_999                                           0.0      0.0
# Operator ID_1248                                          0.0      0.0
# Operator ID_1541                                          0.0      0.0
# ...                                                       ...      ...
# Operator ID_39023                                         0.0      0.0
# Operator ID_39029                                         0.0      0.0
# Operator ID_39043                                         0.0      0.0
# Operator ID_39047                                         0.0      0.0
# Operator ID_39055                                         0.0      0.0
# Operator ID_39068                                         0.0      0.0
# Operator ID_39080                                         0.0      0.0
# Operator ID_39084                                         0.0      0.0
# Operator ID_39085                                         0.0      0.0
# Operator ID_39090                                         0.0      0.0
# Operator ID_39098                                         0.0      0.0
# Operator ID_39104                                         0.0      0.0
# Operator ID_39105                                         0.0      0.0
# Operator ID_39145                                         0.0      0.0
# Operator ID_39149                                         0.0      0.0
# Operator ID_39183                                         0.0      0.0
# Operator ID_39191                                         0.0      0.0
# Operator ID_39229                                         0.0      0.0
# Operator ID_39264                                         0.0      0.0
# Operator ID_39286                                         0.0      0.0
# Operator ID_39302                                         0.0      0.0
# Operator ID_39307                                         0.0      0.0
# Operator ID_39349                                         0.0      0.0
# Operator ID_39440                                         0.0      0.0
# Operator ID_39467                                         0.0      0.0
# Operator ID_39504                                         0.0      0.0
# Operator ID_39509                                         0.0      0.0
# Operator ID_39534                                         0.0      0.0
# Operator ID_99031                                         0.0      0.0
# Operator ID_99043                                         0.0      0.0
#
#                                                       7        8        9     \
# All Costs                                           413.00  40336.0  30050.0
# Net Loss (Barrels)                                    0.24      0.0      0.0
# Shutdown Duration                                     0.00      0.0      0.0
# Pipeline Type_ABOVEGROUND                             1.00      1.0      0.0
# Pipeline Type_TANK                                    0.00      0.0      1.0
# Pipeline Type_TRANSITION AREA                         0.00      0.0      0.0
# Pipeline Type_UNDERGROUND                             0.00      0.0      0.0
# Liquid Type_BIOFUEL / ALTERNATIVE FUEL(INCLUDIN...    0.00      0.0      0.0
# Liquid Type_CO2 (CARBON DIOXIDE)                      0.00      0.0      0.0
# Liquid Type_CRUDE OIL                                 0.00      0.0      0.0
# Liquid Type_HVL OR OTHER FLAMMABLE OR TOXIC FLU...    1.00      0.0      0.0
# Liquid Type_REFINED AND/OR PETROLEUM PRODUCT (N...    0.00      1.0      1.0
# Cause Category_ALL OTHER CAUSES                       0.00      0.0      1.0
# Cause Category_CORROSION                              0.00      0.0      0.0
# Cause Category_EXCAVATION DAMAGE                      0.00      0.0      0.0
# Cause Category_INCORRECT OPERATION                    0.00      0.0      0.0
# Cause Category_MATERIAL/WELD/EQUIP FAILURE            0.00      1.0      0.0
# Cause Category_NATURAL FORCE DAMAGE                   1.00      0.0      0.0
# Cause Category_OTHER OUTSIDE FORCE DAMAGE             0.00      0.0      0.0
# Liquid Ignition_NO                                    0.00      0.0      0.0
# Liquid Ignition_YES                                   1.00      1.0      1.0
# Liquid Explosion_NO                                   0.00      0.0      0.0
# Liquid Explosion_YES                                  1.00      1.0      1.0
# Operator ID_300                                       0.00      0.0      0.0
# Operator ID_395                                       0.00      0.0      0.0
# Operator ID_515                                       0.00      0.0      0.0
# Operator ID_879                                       0.00      0.0      0.0
# Operator ID_999                                       0.00      0.0      0.0
# Operator ID_1248                                      0.00      0.0      0.0
# Operator ID_1541                                      0.00      0.0      0.0
# ...                                                    ...      ...      ...
# Operator ID_39023                                     0.00      0.0      0.0
# Operator ID_39029                                     0.00      0.0      0.0
# Operator ID_39043                                     0.00      0.0      0.0
# Operator ID_39047                                     0.00      0.0      0.0
# Operator ID_39055                                     0.00      0.0      0.0
# Operator ID_39068                                     0.00      0.0      0.0
# Operator ID_39080                                     0.00      0.0      0.0
# Operator ID_39084                                     0.00      0.0      0.0
# Operator ID_39085                                     0.00      0.0      0.0
# Operator ID_39090                                     0.00      0.0      0.0
# Operator ID_39098                                     0.00      0.0      0.0
# Operator ID_39104                                     0.00      0.0      0.0
# Operator ID_39105                                     0.00      0.0      0.0
# Operator ID_39145                                     0.00      0.0      0.0
# Operator ID_39149                                     0.00      0.0      0.0
# Operator ID_39183                                     0.00      0.0      0.0
# Operator ID_39191                                     0.00      0.0      0.0
# Operator ID_39229                                     0.00      0.0      0.0
# Operator ID_39264                                     0.00      0.0      0.0
# Operator ID_39286                                     0.00      0.0      0.0
# Operator ID_39302                                     0.00      0.0      0.0
# Operator ID_39307                                     0.00      0.0      0.0
# Operator ID_39349                                     0.00      0.0      0.0
# Operator ID_39440                                     0.00      0.0      0.0
# Operator ID_39467                                     0.00      0.0      0.0
# Operator ID_39504                                     0.00      0.0      0.0
# Operator ID_39509                                     0.00      0.0      0.0
# Operator ID_39534                                     0.00      0.0      0.0
# Operator ID_99031                                     0.00      0.0      0.0
# Operator ID_99043                                     0.00      0.0      0.0
#
#                                                      ...        2785     2786  \
# All Costs                                            ...     66041.0  47047.0
# Net Loss (Barrels)                                   ...         0.0      0.0
# Shutdown Duration                                    ...        18.0      4.0
# Pipeline Type_ABOVEGROUND                            ...         1.0      1.0
# Pipeline Type_TANK                                   ...         0.0      0.0
# Pipeline Type_TRANSITION AREA                        ...         0.0      0.0
# Pipeline Type_UNDERGROUND                            ...         0.0      0.0
# Liquid Type_BIOFUEL / ALTERNATIVE FUEL(INCLUDIN...   ...         0.0      0.0
# Liquid Type_CO2 (CARBON DIOXIDE)                     ...         0.0      0.0
# Liquid Type_CRUDE OIL                                ...         1.0      1.0
# Liquid Type_HVL OR OTHER FLAMMABLE OR TOXIC FLU...   ...         0.0      0.0
# Liquid Type_REFINED AND/OR PETROLEUM PRODUCT (N...   ...         0.0      0.0
# Cause Category_ALL OTHER CAUSES                      ...         0.0      0.0
# Cause Category_CORROSION                             ...         0.0      0.0
# Cause Category_EXCAVATION DAMAGE                     ...         0.0      0.0
# Cause Category_INCORRECT OPERATION                   ...         0.0      0.0
# Cause Category_MATERIAL/WELD/EQUIP FAILURE           ...         1.0      1.0
# Cause Category_NATURAL FORCE DAMAGE                  ...         0.0      0.0
# Cause Category_OTHER OUTSIDE FORCE DAMAGE            ...         0.0      0.0
# Liquid Ignition_NO                                   ...         0.0      0.0
# Liquid Ignition_YES                                  ...         1.0      1.0
# Liquid Explosion_NO                                  ...         0.0      0.0
# Liquid Explosion_YES                                 ...         1.0      1.0
# Operator ID_300                                      ...         0.0      0.0
# Operator ID_395                                      ...         0.0      0.0
# Operator ID_515                                      ...         0.0      0.0
# Operator ID_879                                      ...         0.0      0.0
# Operator ID_999                                      ...         0.0      0.0
# Operator ID_1248                                     ...         0.0      0.0
# Operator ID_1541                                     ...         0.0      0.0
# ...                                                  ...         ...      ...
# Operator ID_39023                                    ...         0.0      0.0
# Operator ID_39029                                    ...         0.0      0.0
# Operator ID_39043                                    ...         0.0      0.0
# Operator ID_39047                                    ...         0.0      0.0
# Operator ID_39055                                    ...         0.0      0.0
# Operator ID_39068                                    ...         0.0      0.0
# Operator ID_39080                                    ...         0.0      0.0
# Operator ID_39084                                    ...         0.0      0.0
# Operator ID_39085                                    ...         0.0      0.0
# Operator ID_39090                                    ...         0.0      0.0
# Operator ID_39098                                    ...         0.0      0.0
# Operator ID_39104                                    ...         0.0      0.0
# Operator ID_39105                                    ...         0.0      0.0
# Operator ID_39145                                    ...         0.0      0.0
# Operator ID_39149                                    ...         0.0      0.0
# Operator ID_39183                                    ...         0.0      0.0
# Operator ID_39191                                    ...         0.0      0.0
# Operator ID_39229                                    ...         0.0      0.0
# Operator ID_39264                                    ...         0.0      0.0
# Operator ID_39286                                    ...         0.0      0.0
# Operator ID_39302                                    ...         0.0      0.0
# Operator ID_39307                                    ...         0.0      0.0
# Operator ID_39349                                    ...         0.0      0.0
# Operator ID_39440                                    ...         0.0      0.0
# Operator ID_39467                                    ...         0.0      0.0
# Operator ID_39504                                    ...         0.0      0.0
# Operator ID_39509                                    ...         0.0      0.0
# Operator ID_39534                                    ...         0.0      0.0
# Operator ID_99031                                    ...         0.0      0.0
# Operator ID_99043                                    ...         0.0      0.0
#
#                                                        2787      2788  \
# All Costs                                           65075.0  258510.0
# Net Loss (Barrels)                                      0.0       0.0
# Shutdown Duration                                       0.0       0.0
# Pipeline Type_ABOVEGROUND                               1.0       1.0
# Pipeline Type_TANK                                      0.0       0.0
# Pipeline Type_TRANSITION AREA                           0.0       0.0
# Pipeline Type_UNDERGROUND                               0.0       0.0
# Liquid Type_BIOFUEL / ALTERNATIVE FUEL(INCLUDIN...      0.0       0.0
# Liquid Type_CO2 (CARBON DIOXIDE)                        0.0       0.0
# Liquid Type_CRUDE OIL                                   1.0       1.0
# Liquid Type_HVL OR OTHER FLAMMABLE OR TOXIC FLU...      0.0       0.0
# Liquid Type_REFINED AND/OR PETROLEUM PRODUCT (N...      0.0       0.0
# Cause Category_ALL OTHER CAUSES                         1.0       0.0
# Cause Category_CORROSION                                0.0       0.0
# Cause Category_EXCAVATION DAMAGE                        0.0       0.0
# Cause Category_INCORRECT OPERATION                      0.0       0.0
# Cause Category_MATERIAL/WELD/EQUIP FAILURE              0.0       1.0
# Cause Category_NATURAL FORCE DAMAGE                     0.0       0.0
# Cause Category_OTHER OUTSIDE FORCE DAMAGE               0.0       0.0
# Liquid Ignition_NO                                      0.0       0.0
# Liquid Ignition_YES                                     1.0       1.0
# Liquid Explosion_NO                                     0.0       0.0
# Liquid Explosion_YES                                    1.0       1.0
# Operator ID_300                                         0.0       0.0
# Operator ID_395                                         0.0       0.0
# Operator ID_515                                         0.0       0.0
# Operator ID_879                                         0.0       0.0
# Operator ID_999                                         0.0       0.0
# Operator ID_1248                                        0.0       0.0
# Operator ID_1541                                        0.0       0.0
# ...                                                     ...       ...
# Operator ID_39023                                       0.0       0.0
# Operator ID_39029                                       0.0       0.0
# Operator ID_39043                                       0.0       0.0
# Operator ID_39047                                       0.0       0.0
# Operator ID_39055                                       0.0       0.0
# Operator ID_39068                                       0.0       0.0
# Operator ID_39080                                       0.0       0.0
# Operator ID_39084                                       0.0       0.0
# Operator ID_39085                                       0.0       0.0
# Operator ID_39090                                       0.0       0.0
# Operator ID_39098                                       0.0       0.0
# Operator ID_39104                                       0.0       0.0
# Operator ID_39105                                       0.0       0.0
# Operator ID_39145                                       0.0       0.0
# Operator ID_39149                                       0.0       0.0
# Operator ID_39183                                       0.0       0.0
# Operator ID_39191                                       0.0       0.0
# Operator ID_39229                                       0.0       0.0
# Operator ID_39264                                       0.0       0.0
# Operator ID_39286                                       0.0       0.0
# Operator ID_39302                                       0.0       0.0
# Operator ID_39307                                       0.0       0.0
# Operator ID_39349                                       0.0       0.0
# Operator ID_39440                                       0.0       0.0
# Operator ID_39467                                       0.0       0.0
# Operator ID_39504                                       0.0       0.0
# Operator ID_39509                                       0.0       0.0
# Operator ID_39534                                       0.0       0.0
# Operator ID_99031                                       0.0       0.0
# Operator ID_99043                                       0.0       0.0
#
#                                                        2789     2790  \
# All Costs                                           13120.0  61015.0
# Net Loss (Barrels)                                      1.0      0.0
# Shutdown Duration                                       2.0      7.0
# Pipeline Type_ABOVEGROUND                               1.0      1.0
# Pipeline Type_TANK                                      0.0      0.0
# Pipeline Type_TRANSITION AREA                           0.0      0.0
# Pipeline Type_UNDERGROUND                               0.0      0.0
# Liquid Type_BIOFUEL / ALTERNATIVE FUEL(INCLUDIN...      0.0      0.0
# Liquid Type_CO2 (CARBON DIOXIDE)                        0.0      0.0
# Liquid Type_CRUDE OIL                                   1.0      1.0
# Liquid Type_HVL OR OTHER FLAMMABLE OR TOXIC FLU...      0.0      0.0
# Liquid Type_REFINED AND/OR PETROLEUM PRODUCT (N...      0.0      0.0
# Cause Category_ALL OTHER CAUSES                         0.0      0.0
# Cause Category_CORROSION                                1.0      0.0
# Cause Category_EXCAVATION DAMAGE                        0.0      0.0
# Cause Category_INCORRECT OPERATION                      0.0      0.0
# Cause Category_MATERIAL/WELD/EQUIP FAILURE              0.0      1.0
# Cause Category_NATURAL FORCE DAMAGE                     0.0      0.0
# Cause Category_OTHER OUTSIDE FORCE DAMAGE               0.0      0.0
# Liquid Ignition_NO                                      0.0      0.0
# Liquid Ignition_YES                                     1.0      1.0
# Liquid Explosion_NO                                     0.0      0.0
# Liquid Explosion_YES                                    1.0      1.0
# Operator ID_300                                         0.0      0.0
# Operator ID_395                                         0.0      0.0
# Operator ID_515                                         0.0      0.0
# Operator ID_879                                         0.0      0.0
# Operator ID_999                                         0.0      0.0
# Operator ID_1248                                        0.0      0.0
# Operator ID_1541                                        0.0      0.0
# ...                                                     ...      ...
# Operator ID_39023                                       0.0      0.0
# Operator ID_39029                                       0.0      0.0
# Operator ID_39043                                       0.0      0.0
# Operator ID_39047                                       0.0      0.0
# Operator ID_39055                                       0.0      0.0
# Operator ID_39068                                       0.0      0.0
# Operator ID_39080                                       0.0      0.0
# Operator ID_39084                                       0.0      0.0
# Operator ID_39085                                       0.0      0.0
# Operator ID_39090                                       0.0      0.0
# Operator ID_39098                                       0.0      0.0
# Operator ID_39104                                       0.0      0.0
# Operator ID_39105                                       0.0      0.0
# Operator ID_39145                                       0.0      0.0
# Operator ID_39149                                       0.0      0.0
# Operator ID_39183                                       0.0      0.0
# Operator ID_39191                                       0.0      0.0
# Operator ID_39229                                       0.0      0.0
# Operator ID_39264                                       0.0      0.0
# Operator ID_39286                                       0.0      0.0
# Operator ID_39302                                       0.0      0.0
# Operator ID_39307                                       0.0      0.0
# Operator ID_39349                                       0.0      0.0
# Operator ID_39440                                       0.0      0.0
# Operator ID_39467                                       0.0      0.0
# Operator ID_39504                                       0.0      0.0
# Operator ID_39509                                       0.0      0.0
# Operator ID_39534                                       0.0      0.0
# Operator ID_99031                                       0.0      0.0
# Operator ID_99043                                       0.0      0.0
#
#                                                         2791     2792  \
# All Costs                                           105400.0  15050.0
# Net Loss (Barrels)                                     580.0      0.0
# Shutdown Duration                                        0.0      0.0
# Pipeline Type_ABOVEGROUND                                0.0      0.0
# Pipeline Type_TANK                                       0.0      1.0
# Pipeline Type_TRANSITION AREA                            0.0      0.0
# Pipeline Type_UNDERGROUND                                1.0      0.0
# Liquid Type_BIOFUEL / ALTERNATIVE FUEL(INCLUDIN...       0.0      0.0
# Liquid Type_CO2 (CARBON DIOXIDE)                         0.0      0.0
# Liquid Type_CRUDE OIL                                    0.0      1.0
# Liquid Type_HVL OR OTHER FLAMMABLE OR TOXIC FLU...       1.0      0.0
# Liquid Type_REFINED AND/OR PETROLEUM PRODUCT (N...       0.0      0.0
# Cause Category_ALL OTHER CAUSES                          1.0      0.0
# Cause Category_CORROSION                                 0.0      0.0
# Cause Category_EXCAVATION DAMAGE                         0.0      0.0
# Cause Category_INCORRECT OPERATION                       0.0      0.0
# Cause Category_MATERIAL/WELD/EQUIP FAILURE               0.0      1.0
# Cause Category_NATURAL FORCE DAMAGE                      0.0      0.0
# Cause Category_OTHER OUTSIDE FORCE DAMAGE                0.0      0.0
# Liquid Ignition_NO                                       0.0      0.0
# Liquid Ignition_YES                                      1.0      1.0
# Liquid Explosion_NO                                      0.0      0.0
# Liquid Explosion_YES                                     1.0      1.0
# Operator ID_300                                          0.0      0.0
# Operator ID_395                                          0.0      0.0
# Operator ID_515                                          0.0      0.0
# Operator ID_879                                          0.0      0.0
# Operator ID_999                                          0.0      0.0
# Operator ID_1248                                         0.0      0.0
# Operator ID_1541                                         0.0      0.0
# ...                                                      ...      ...
# Operator ID_39023                                        0.0      0.0
# Operator ID_39029                                        0.0      0.0
# Operator ID_39043                                        0.0      0.0
# Operator ID_39047                                        0.0      0.0
# Operator ID_39055                                        0.0      0.0
# Operator ID_39068                                        0.0      0.0
# Operator ID_39080                                        0.0      0.0
# Operator ID_39084                                        0.0      0.0
# Operator ID_39085                                        0.0      0.0
# Operator ID_39090                                        0.0      0.0
# Operator ID_39098                                        0.0      0.0
# Operator ID_39104                                        0.0      0.0
# Operator ID_39105                                        0.0      0.0
# Operator ID_39145                                        0.0      1.0
# Operator ID_39149                                        0.0      0.0
# Operator ID_39183                                        0.0      0.0
# Operator ID_39191                                        0.0      0.0
# Operator ID_39229                                        0.0      0.0
# Operator ID_39264                                        0.0      0.0
# Operator ID_39286                                        0.0      0.0
# Operator ID_39302                                        0.0      0.0
# Operator ID_39307                                        0.0      0.0
# Operator ID_39349                                        0.0      0.0
# Operator ID_39440                                        0.0      0.0
# Operator ID_39467                                        0.0      0.0
# Operator ID_39504                                        0.0      0.0
# Operator ID_39509                                        0.0      0.0
# Operator ID_39534                                        0.0      0.0
# Operator ID_99031                                        0.0      0.0
# Operator ID_99043                                        0.0      0.0
#
#                                                        2793     2794
# All Costs                                           41428.0  45800.0
# Net Loss (Barrels)                                      0.0      0.0
# Shutdown Duration                                       0.0      0.0
# Pipeline Type_ABOVEGROUND                               0.0      1.0
# Pipeline Type_TANK                                      0.0      0.0
# Pipeline Type_TRANSITION AREA                           0.0      0.0
# Pipeline Type_UNDERGROUND                               1.0      0.0
# Liquid Type_BIOFUEL / ALTERNATIVE FUEL(INCLUDIN...      0.0      0.0
# Liquid Type_CO2 (CARBON DIOXIDE)                        0.0      0.0
# Liquid Type_CRUDE OIL                                   0.0      1.0
# Liquid Type_HVL OR OTHER FLAMMABLE OR TOXIC FLU...      0.0      0.0
# Liquid Type_REFINED AND/OR PETROLEUM PRODUCT (N...      1.0      0.0
# Cause Category_ALL OTHER CAUSES                         1.0      0.0
# Cause Category_CORROSION                                0.0      0.0
# Cause Category_EXCAVATION DAMAGE                        0.0      0.0
# Cause Category_INCORRECT OPERATION                      0.0      1.0
# Cause Category_MATERIAL/WELD/EQUIP FAILURE              0.0      0.0
# Cause Category_NATURAL FORCE DAMAGE                     0.0      0.0
# Cause Category_OTHER OUTSIDE FORCE DAMAGE               0.0      0.0
# Liquid Ignition_NO                                      0.0      0.0
# Liquid Ignition_YES                                     1.0      1.0
# Liquid Explosion_NO                                     0.0      0.0
# Liquid Explosion_YES                                    1.0      1.0
# Operator ID_300                                         0.0      0.0
# Operator ID_395                                         0.0      0.0
# Operator ID_515                                         0.0      0.0
# Operator ID_879                                         0.0      0.0
# Operator ID_999                                         0.0      0.0
# Operator ID_1248                                        0.0      0.0
# Operator ID_1541                                        0.0      0.0
# ...                                                     ...      ...
# Operator ID_39023                                       0.0      0.0
# Operator ID_39029                                       0.0      0.0
# Operator ID_39043                                       0.0      0.0
# Operator ID_39047                                       0.0      0.0
# Operator ID_39055                                       0.0      0.0
# Operator ID_39068                                       0.0      0.0
# Operator ID_39080                                       0.0      0.0
# Operator ID_39084                                       0.0      0.0
# Operator ID_39085                                       0.0      0.0
# Operator ID_39090                                       0.0      0.0
# Operator ID_39098                                       0.0      0.0
# Operator ID_39104                                       0.0      0.0
# Operator ID_39105                                       0.0      0.0
# Operator ID_39145                                       0.0      0.0
# Operator ID_39149                                       0.0      0.0
# Operator ID_39183                                       0.0      0.0
# Operator ID_39191                                       0.0      0.0
# Operator ID_39229                                       0.0      0.0
# Operator ID_39264                                       0.0      0.0
# Operator ID_39286                                       0.0      0.0
# Operator ID_39302                                       0.0      0.0
# Operator ID_39307                                       0.0      0.0
# Operator ID_39349                                       0.0      0.0
# Operator ID_39440                                       0.0      0.0
# Operator ID_39467                                       0.0      0.0
# Operator ID_39504                                       0.0      0.0
# Operator ID_39509                                       0.0      0.0
# Operator ID_39534                                       0.0      0.0
# Operator ID_99031                                       0.0      0.0
# Operator ID_99043                                       0.0      0.0
#
# [236 rows x 2795 columns]

# %% [markdown]
# # Modelling and regression

# %%
# %matplotlib inline
from sklearn.linear_model import Lasso, LassoCV, Ridge, RidgeCV
from sklearn.model_selection import cross_val_predict, train_test_split, cross_val_score
from sklearn.ensemble import RandomForestRegressor, BaggingClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import r2_score
from yellowbrick.regressor import AlphaSelection, PredictionError, ResidualsPlot
import math
import sklearn.metrics as metrics

# %%
dataframe = newdf.copy()

dataframe['Log All Costs'] = y_log
print(dataframe['Log All Costs'].describe())
dataframe['Log All Costs'].plot(kind='hist')
# Out:
# count    2795.000000
# mean       10.006837
# std         2.629996
# min         0.000000
# 25%         8.525062
# 50%        10.048843
# 75%        11.671913
# max        20.549539
# Name: Log All Costs, dtype: float64

# %%
# Extract the X and y data from the dataframe
l = len(newdf.columns)
X = dataframe.iloc[:,1:l]
y = dataframe['All Costs']

y_log = np.log(dataframe['All Costs'])
y_log = y_log.replace([np.inf, -np.inf], np.nan).fillna(0)  # Replace -inf with 0

# Create the train and test data 
X_train, X_test, y_train, y_test = train_test_split(X, y_log, test_size=0.3) # seems to be the sample optimal test size

# %%
# Instantiate the linear model and visualizer
model = Ridge()
visualizer = ResidualsPlot(model)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data 
g = visualizer.poof()             # Draw/show/poof the data

# %% [raw]
# As per this graph, Ridge model or any linear model won't correctly fit our data. The difference of R² between train ant test sets indicates the Ridge model is over-fitting
# Neither linear nor polynomial model seem adapted to modelize this dataset

# %% [raw]
# Add R² formula...

# %% [raw]
# Use of (Bagging) meta-estimators

# %% [raw]
# The KNeighborsClassifier or random forest regressor use kNN or decision trees on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting

# %%
# Extract columnson train X
X2= X
y2= y

# Model creation and fit
model1 = BaggingClassifier(KNeighborsClassifier())
model1.fit(X2,y2)

# Show model results of training set
y2_hat = model1.predict(X2)
mae = metrics.mean_absolute_error(y2,y2_hat)
mse = metrics.mean_squared_error(y2,y2_hat)
print ("TRAINING SET")
print ("=========================================")
print ("MAE:         ", mae)
print ("MSE:         ", math.sqrt(mse))
print ("r2:          ", model1.score(X2,y2))
print ("n_features:  ", model1.n_features_)

# Show model results of test set
y_hat_test = model1.predict(X_test)
mae = metrics.mean_absolute_error(y_test,y_hat_test)
mse = metrics.mean_squared_error(y_test,y_hat_test)
print ("TEST SET")
print ("=========================================")
print ("MAE:                ", mae)
print ("RMSE:               ", math.sqrt(mse))
print ("r2:                 ", model1.score(X_test,y_test))
print ("r2 retry:           ", r2_score(y_test, y_hat_test))
print ("n_features:         ", model1.n_features_)
# Out:
# TRAINING SET
# =========================================
# MAE:          774472.6568872988
# MSE:          16227498.019697156
# r2:           0.37245080500894456
# n_features:   235
# TEST SET
# =========================================
# MAE:                 315752.4705047793
# RMSE:                1513239.9250241914
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-dabd49b501d6> in <module>
#      26 print ("MAE:                ", mae)
#      27 print ("RMSE:               ", math.sqrt(mse))
# ---> 28 print ("r2:                 ", model1.score(X_test,y_test))
#      29 print ("r2 retry:           ", r2_score(y_test, y_hat_test))
#      30 print ("n_features:         ", model1.n_features_)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     286         """
#     287         from .metrics import accuracy_score
# --> 288         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     289
#     290
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     check_consistent_length(y_true, y_pred, sample_weight)
#     178     if y_type.startswith('multilabel'):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      79     if len(y_type) > 1:
#      80         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 81                          "and {1} targets".format(type_true, type_pred))
#      82
#      83     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of continuous and multiclass targets

# %%
# AdaBoost
model2 = AdaBoostClassifier(n_estimators=50)
scores = cross_val_score(model2, X2, y2, cv=5) # Cross-Validation
scores.mean()
# Out:
# 0.07759245262371879

# %%
# Extract columnson train X
X2= X
y2= y_log

# Model creation and fit
model3 = RandomForestRegressor()
model3.fit(X2,y2)

# Show model results of training set
y2_hat = model3.predict(X2)
mae = metrics.mean_absolute_error(y2,y2_hat)
mse = metrics.mean_squared_error(y2,y2_hat)
print ("TRAINING SET")
print ("=========================================")
print ("MAE:                ", mae)
print ("MSE:                ", math.sqrt(mse))
print ("r2:                 ", model3.score(X2,y2))
print ("n_features:         ", model3.n_features_)
print ("n_outputs:          ", model3.n_outputs_)

# Show model results of test set
y_hat_test = model3.predict(X_test)
mae = metrics.mean_absolute_error(y_test,y_hat_test)
mse = metrics.mean_squared_error(y_test,y_hat_test)
print ("TEST SET")
print ("=========================================")
print ("MAE:                ", mae)
print ("RMSE:               ", math.sqrt(mse))
print ("r2:                 ", model3.score(X_test,y_test))
print ("r2 retry:           ", r2_score(y_test, y_hat_test))
print ("n_features:         ", model3.n_features_)
print ("n_outputs:          ", model3.n_outputs_)
# Out:
# TRAINING SET
# =========================================
# MAE:                 0.7330964718047928
# MSE:                 1.1097001636885806
# r2:                  0.8219030501992844
# n_features:          235
# n_outputs:           1
# TEST SET
# =========================================
# MAE:                 0.7446935531451309
# RMSE:                1.1111468355516894
# r2:                  0.8252343800620522
# r2 retry:            0.8252343800620521
# n_features:          235
# n_outputs:           1

# %% [markdown]
# # Conclusion

# %% [raw]
# Meta estimator such as randomforestRegressor are much more efficient and accurate than simple regressor models. With a R² higher than 80%, far ahead of linear regression models, it allows acceptable cost prediction of pipeline accident.
